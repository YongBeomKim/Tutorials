# %% [markdown]
# # <strong>D3 Basic Functions
# <br>
# ## <strong>1. D3 기본 컨트롤
# 기본 객체의 속성변경

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     #myGraph2 svg {width: 320px; height: 100px; border: 1px solid black;}
# </style>
# </head>
# <body>
#     <h1> 1) D3 속성을 Json으로 묶어서 삽입하기 </h1>
#     <div id="myGraph2"></div>
#     <script>
#     d3.select("#myGraph2")	                        // ID 이름에 myBar를 지정
#       .append("svg").append("rect")
#       .attr({ x : "10px", y : "50px",               // X 좌표를 10px, Y 좌표를 50px
#               width : "250px", height : "30px",})   // 넓이를 200px, 높이를 30px
#       .style("fill","green")
#       .style("stroke","black");
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     #myGraph2 svg {width: 320px; height: 100px; border: 1px solid black;}
# </style>
# </head>
# <body>
#     <h1> 1) D3 속성을 Json으로 묶어서 삽입하기 </h1>
#     <div id="myGraph2"></div>
#     <script>
#     d3.select("#myGraph2")	                        // ID 이름에 myBar를 지정
#       .append("svg").append("rect")
#       .attr({ x : "10px", y : "50px",               // X 좌표를 10px, Y 좌표를 50px
#               width : "250px", height : "30px",})   // 넓이를 200px, 높이를 30px
#       .style("fill","green")
#       .style("stroke","black");
#     </script>
# </body>

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
# svg#myGraph3 { width: 320px; height: 100px; border: 1px solid black;}
# #myGraph3 rect {fill: orange;}
# </style>
# </head>
# <body>
#     <h1> 2) D3.js의 SVG 속성으로 간단한 Animation 활용</h1>
#     <svg id="myGraph3">
#         <rect id="bar" x="0" y="50" width="100" height="25" />
#     </svg>
#     <script>
#     d3.select("#bar")            	// ID 위치를 연결
#       .attr({ x : "10px",      y : "50px",
#               width : "200px", height : "30px",})
#       .transition()                 // 애니메이션 설정
#       .duration(5000)               // 3초간 변화
#       .attr("width","50px")        // 넓이를 50px로 설정
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
# svg#myGraph3 { width: 320px; height: 100px; border: 1px solid black;}
# #myGraph3 rect {fill: orange;}
# </style>
# </head>
# <body>
#     <h1> 2) D3.js의 SVG 속성으로 간단한 Animation 활용</h1>
#     <svg id="myGraph3">
#         <rect id="bar" x="0" y="50" width="100" height="25" />
#     </svg>
#     <script>
#     d3.select("#bar")            	// ID 위치를 연결
#       .attr({ x : "10px",      y : "50px",
#               width : "200px", height : "30px",})
#       .transition()                 // 애니메이션 설정
#       .duration(5000)               // 3초간 변화
#       .attr("width","50px")        // 넓이를 50px로 설정
#     </script>
# </body>

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     #bar svg { width: 320px; height: 240px; border: 1px solid black; }
#     .bar2 { fill : orange; }
#     .bar_note { fill : red; }
# </style>
# </head>
# <body>
#     <h1> 3) D3.js의 스타일 CSS와 연계하여 다루기 </h1>
#     <svg id="bar">
#         <rect class="bar2" x="0" y="10" width="60" height="25" />
#         <rect class="bar2" x="0" y="50" width="100" height="25" />
#         <rect class="bar2" x="0" y="90" width="160" height="25" />
#         <rect class="bar2" x="0" y="130" width="220" height="25" />
#     </svg>
#     <script>
#     d3.select(".bar2")
#       .attr("class","bar_note")  //CSS 속성으로 객체를 변경 (Control이 더 용이하다)
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     #bar svg { width: 320px; height: 240px; border: 1px solid black; }
#     .bar2 { fill : orange; }
#     .bar_note { fill : red; }
# </style>
# </head>
# <body>
#     <h1> 3) D3.js의 스타일 CSS와 연계하여 다루기 </h1>
#     <svg id="bar">
#         <rect class="bar2" x="0" y="10" width="60" height="25" />
#         <rect class="bar2" x="0" y="50" width="100" height="25" />
#         <rect class="bar2" x="0" y="90" width="160" height="25" />
#         <rect class="bar2" x="0" y="130" width="220" height="25" />
#     </svg>
#     <script>
#     d3.select(".bar2")
#       .attr("class","bar_note")  //CSS 속성으로 객체를 변경 (Control이 더 용이하다)
#     </script>
# </body>

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         #box3 svg { width: 320px; height: 240px; border: 1px solid black; }
#         .bar3 { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 4) D3.js의 Json 스타일 CSS과 함께 적용 </h1>
#     <svg id="box3">
#         <rect class="bar3" x="0" y="10" width="60" height="25" />
#         <rect class="bar3" x="0" y="50" width="100" height="25" />
#         <rect class="bar3" x="0" y="90" width="160" height="25" />
#         <rect class="bar3" x="0" y="130" width="220" height="25" />
#     </svg>`
#     <script>
#     d3.select(".bar3")	                        // CSS 클래스 이름에 bar를 지정
#       .attr("style","fill:red; stroke:black");  // Json 포맷으로 스타일 일괄 지정
# </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         #box3 svg { width: 320px; height: 240px; border: 1px solid black; }
#         .bar3 { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 4) D3.js의 Json 스타일 CSS과 함께 적용 </h1>
#     <svg id="box3">
#         <rect class="bar3" x="0" y="10" width="60" height="25" />
#         <rect class="bar3" x="0" y="50" width="100" height="25" />
#         <rect class="bar3" x="0" y="90" width="160" height="25" />
#         <rect class="bar3" x="0" y="130" width="220" height="25" />
#     </svg>`
#     <script>
#     d3.select(".bar3")	                        // CSS 클래스 이름에 bar를 지정
#       .attr("style","fill:red; stroke:black");  // Json 포맷으로 스타일 일괄 지정
# </script>
# </body>

# %% [markdown]
# <br><br>
# ## <strong>2. D3 조건에 따른 컨트롤
# 객체의 속성변경

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         #box4 svg { width: 320px; height: 240px; border: 1px solid black; }
#         .bar4 { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 1) 규칙을 활용하여 객체를 특정 </h1>
#     <svg id="box4">
#         <rect class="bar4" x="0" y="10" width="60" height="25" />
#         <rect class="bar4" x="0" y="50" width="100" height="25" />
#         <rect class="bar4" x="0" y="90" width="160" height="25" />
#         <rect class="bar4" x="0" y="130" width="220" height="25" />
#     </svg>
#     <script>
#     d3.selectAll(".bar4")                    // CSS 클래스 이름에 bar를 지정
#       .style("fill", function(data, index){  // 2번째의 파라미터에 함수를 지정
#         if(index % 2 == 0){                  // 순서 규칙을 정의 및 적용
#         return "red";}                       // 3번째라면 빨간색을 나타내는 문자를 반환
#       });
# </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         #box4 svg { width: 320px; height: 240px; border: 1px solid black; }
#         .bar4 { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 1) 규칙을 활용하여 객체를 특정 </h1>
#     <svg id="box4">
#         <rect class="bar4" x="0" y="10" width="60" height="25" />
#         <rect class="bar4" x="0" y="50" width="100" height="25" />
#         <rect class="bar4" x="0" y="90" width="160" height="25" />
#         <rect class="bar4" x="0" y="130" width="220" height="25" />
#     </svg>
#     <script>
#     d3.selectAll(".bar4")                    // CSS 클래스 이름에 bar를 지정
#       .style("fill", function(data, index){  // 2번째의 파라미터에 함수를 지정
#         if(index % 2 == 0){                  // 순서 규칙을 정의 및 적용
#         return "red";}                       // 3번째라면 빨간색을 나타내는 문자를 반환
#       });
# </script>
# </body>

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         #box5 svg { width: 320px; height: 240px; border: 1px solid black; }
#         .bar5 { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 2) 조건문을 활용하여 객체를 특정 </h1>
#     <svg id="box5">
#         <rect class="bar5" x="0" y="10" width="60" height="25" />
#         <rect class="bar5" x="0" y="50" width="100" height="25" />
#         <rect class="bar5" x="0" y="90" width="160" height="25" />
#         <rect class="bar5" x="0" y="130" width="220" height="25" />
#     </svg>
#     <script>
#     d3.selectAll(".bar5")                    // CSS 클래스 이름에 bar를 지정
#       .style("fill", function(data, index){  // 2번째의 파라미터에 함수를 지정
#         if(index ==1 || index== 2){          // 순서를 조사
#         return "red";}                       // 3번째라면 빨간색을 나타내는 문자를 반환
#       });
# </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         #box5 svg { width: 320px; height: 240px; border: 1px solid black; }
#         .bar5 { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 2) 조건문을 활용하여 객체를 특정 </h1>
#     <svg id="box5">
#         <rect class="bar5" x="0" y="10" width="60" height="25" />
#         <rect class="bar5" x="0" y="50" width="100" height="25" />
#         <rect class="bar5" x="0" y="90" width="160" height="25" />
#         <rect class="bar5" x="0" y="130" width="220" height="25" />
#     </svg>
#     <script>
#     d3.selectAll(".bar5")                    // CSS 클래스 이름에 bar를 지정
#       .style("fill", function(data, index){  // 2번째의 파라미터에 함수를 지정
#         if(index ==1 || index== 2){          // 순서를 조사
#         return "red";}                       // 3번째라면 빨간색을 나타내는 문자를 반환
#       });
# </script>
# </body>

# %% [markdown]
# <br><br>
# ## <strong>3. Array/ CSV/ Json/ XML 을 활용한 시각화
# 객체의 속성변경

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_ex { width: 320px; height: 190px; border: 1px solid black; }
#         #myGraph_ex .bar { fill : green; }
#     </style>
# </head>
# <body>
#     <h1> 1) Array 데이터로 그래프 표시</h1>
#     <svg id="myGraph_ex"></svg>
#     <script>
#     var dataSet = [ 50, 10, 120, 200, 90, 120, 150 ]; // 배열 데이터
#     d3.select("#myGraph_ex")
#       .selectAll("rect").data(dataSet)   // dataSet 모두를 "rect"와 연결
#       .enter().append("rect")            // 연결한 "rect"를 템플릿에 삽입
#       .attr({"class":"bar", "height":20,
#              "width":function(d,i){return d;},   // bar 의 넓이값
#              "x":0,                              // X 좌표를 0으로 함
#              "y":function(d,i){return i*25;},}); // Y 좌표를 지정함 (순서에 25를 곱함)
#     </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_ex { width: 320px; height: 190px; border: 1px solid black; }
#         #myGraph_ex .bar { fill : green; }
#     </style>
# </head>
# <body>
#     <h1> 1) Array 데이터로 그래프 표시</h1>
#     <svg id="myGraph_ex"></svg>
#     <script>
#     var dataSet = [ 50, 10, 120, 200, 90, 120, 150 ]; // 배열 데이터
#     d3.select("#myGraph_ex")
#       .selectAll("rect").data(dataSet)   // dataSet 모두를 "rect"와 연결
#       .enter().append("rect")            // 연결한 "rect"를 템플릿에 삽입
#       .attr({"class":"bar", "height":20,
#              "width":function(d,i){return d;},   // bar 의 넓이값
#              "x":0,                              // X 좌표를 0으로 함
#              "y":function(d,i){return i*25;},}); // Y 좌표를 지정함 (순서에 25를 곱함)
#     </script>
# </body>

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_ex2 { width: 320px; height: 150px; border: 1px solid black; }
#     #myGraph_ex2 .bar { fill : rgb(250,200,100); }
# </style>
# </head>
# <body>
#     <h1> 2. CSV 데이터로 그래프 표시</h1>
#     <svg id="myGraph_ex2"></svg>
#     <script>
#     d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata.csv",
#            function(error, data){var dataSet = [];
#                 for(var i=0; i<data.length; i++){
#                     dataSet.push(data[i].item1);    // CSV_data를 dataSet에 하니씩 전달
#                     }
#         d3.select("#myGraph_ex2")
#           .selectAll("rect").data(dataSet).enter().append("rect")
#           .attr({"class":"bar",      "width":function(d,i){return d;},
#                  "height":20, "x":0, "y":function(d, i){return i * 25},});
#         });
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_ex2 { width: 320px; height: 150px; border: 1px solid black; }
#     #myGraph_ex2 .bar { fill : rgb(250,200,100); }
# </style>
# </head>
# <body>
#     <h1> 2. CSV 데이터로 그래프 표시</h1>
#     <svg id="myGraph_ex2"></svg>
#     <script>
#     d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata.csv",
#            function(error, data){var dataSet = [];
#                 for(var i=0; i<data.length; i++){
#                     dataSet.push(data[i].item1);    // CSV_data를 dataSet에 하니씩 전달
#                     }
#         d3.select("#myGraph_ex2")
#           .selectAll("rect").data(dataSet).enter().append("rect")
#           .attr({"class":"bar",      "width":function(d,i){return d;},
#                  "height":20, "x":0, "y":function(d, i){return i * 25},});
#         });
#     </script>
# </body>

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg#myGraph_ex3 {width: 320px; height: 150px; border: 1px solid black;}
#     #myGraph_ex3 .bar {fill: red;}
#     </style>
# </head>
# <body>
#     <h1> 3. CSV '한글컬럼'을 영어로 변환 후 그리기</h1>
#     <svg id="myGraph_ex3"></svg>
#     <script>
#     d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2.csv")
#       .row(function(data,index){             // 한글 컬럼을 영어로 변경
#                 return {item1 : data["상품A"],
#                         item2 : data["상품B"],
#                         item3 : data["상품C"],} })
#       .get(function(error,data){
#             var dataSet = [];
#             for (var i=0; i<data.length; i++){
#                 dataSet.push(data[i].item1)  // 상품A＝item1 컬럼 데이터만 추출
#                 }                            // alert(JSON.stringify(data));
#             d3.select("#myGraph_ex3")
#               .selectAll("rect").data(dataSet).enter().append("rect")
#               .attr({"class":"bar",      "width":function(d,i){return d},
#                      "height":20, "x":0, "y":function(d, i){return i * 25},});
#             });
#     </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg#myGraph_ex3 {width: 320px; height: 150px; border: 1px solid black;}
#     #myGraph_ex3 .bar {fill: red;}
#     </style>
# </head>
# <body>
#     <h1> 3. CSV '한글컬럼'을 영어로 변환 후 그리기</h1>
#     <svg id="myGraph_ex3"></svg>
#     <script>
#     d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2.csv")
#       .row(function(data,index){             // 한글 컬럼을 영어로 변경
#                 return {item1 : data["상품A"],
#                         item2 : data["상품B"],
#                         item3 : data["상품C"],} })
#       .get(function(error,data){
#             var dataSet = [];
#             for (var i=0; i<data.length; i++){
#                 dataSet.push(data[i].item1)  // 상품A＝item1 컬럼 데이터만 추출
#                 }                            // alert(JSON.stringify(data));
#             d3.select("#myGraph_ex3")
# ...

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg#myGraph_ex4 {width: 320px; height: 130px; border: 1px solid black;}
#     #myGraph_ex4 .bar {fill: red;}
#     </style>
# </head>
# <body>
#     <h1> 4. JSON 데이터로 그래프 그리기</h1>
#     <svg id="myGraph_ex4"></svg>
#     <script>
#     d3.json("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata.json",
#             function(error, data){
#                 var dataSet = [];
#                 for(var i=0; i<data.length; i++){
#                     dataSet.push(data[i].sales[1]);
#                     } //alert(JSON.stringify(dataSet));
#     d3.select("#myGraph_ex4")
#       .selectAll("rect").data(dataSet).enter().append("rect")
#       .attr({"class":"bar"     , "width": function(d,i){return d;},
#              "height":20, "x":0, "y"    : function(d,i){return i * 25},});
#     });
#     </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg#myGraph_ex4 {width: 320px; height: 130px; border: 1px solid black;}
#     #myGraph_ex4 .bar {fill: red;}
#     </style>
# </head>
# <body>
#     <h1> 4. JSON 데이터로 그래프 그리기</h1>
#     <svg id="myGraph_ex4"></svg>
#     <script>
#     d3.json("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata.json",
#             function(error, data){
#                 var dataSet = [];
#                 for(var i=0; i<data.length; i++){
#                     dataSet.push(data[i].sales[1]);
#                     } //alert(JSON.stringify(dataSet));
#     d3.select("#myGraph_ex4")
#       .selectAll("rect").data(dataSet).enter().append("rect")
#       .attr({"class":"bar"     , "width": function(d,i){return d;},
#              "height":20, "x":0, "y"    : function(d,i){return i * 25},});
#     });
#     </script>
# </body>

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg {width: 320px; height: 240px; border: 1px solid black;}
#     .bar {fill: skyblue;}
#     </style>
# </head>
# <body>
#     <h1> 5. HTML 테이블 데이터 그래프 그리기</h1>
#     <svg id="myGraph_ex5"></svg>
#     <script>
#     d3.html("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata.html",
#             function(error, data){
#                   var tr = data.querySelectorAll("table tr");      // table 요소에서 tr 요소를 추출
#                   var dataSet = [];                                // alert(JSON.stringify(tr));
#                   for(var i=1; i<tr.length; i++){                  // querySelectorAll("td")[0] : 첫번째 컬럼 데이터 추출
#                       var data = tr[i].querySelectorAll("td")[0].firstChild.nodeValue;
#                       dataSet.push(data);
#                      }
#                   d3.select("#myGraph_ex5")
#                     .selectAll("rect").data(dataSet).enter().append("rect")
#                     .attr({"class":"bar",      "width":function(d,i){return d;},
#                          "height":20, "x":0, "y":function(d,i){return i*25},});
#             });
#     </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg {width: 320px; height: 240px; border: 1px solid black;}
#     .bar {fill: skyblue;}
#     </style>
# </head>
# <body>
#     <h1> 5. HTML 테이블 데이터 그래프 그리기</h1>
#     <svg id="myGraph_ex5"></svg>
#     <script>
#     d3.html("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata.html",
#             function(error, data){
#                   var tr = data.querySelectorAll("table tr");      // table 요소에서 tr 요소를 추출
#                   var dataSet = [];                                // alert(JSON.stringify(tr));
#                   for(var i=1; i<tr.length; i++){                  // querySelectorAll("td")[0] : 첫번째 컬럼 데이터 추출
#                       var data = tr[i].querySelectorAll("td")[0].firstChild.nodeValue;
#                       dataSet.push(data);
#                      }
#                   d3.select("#myGraph_ex5")
# ...

# %% [markdown]
# <br><br>
# ## <strong>4. Event와 데이터를 연계한 D3 시각화
# chart Button

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_bt { width: 320px; height: 130px; border: 1px solid black; }
#         #myGraph_bt .bar { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 1. CSV 파일에 따른 그래프 바꾸기 </h1>
#     <div>
#         <button csv_src1="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata1.csv">mydata1.csv 불러오기</button>
#         <button csv_src1="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2.csv">mydata2.csv 불러오기</button>
#         <button csv_src1="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata3.csv">mydata3.csv 불러오기</button>
#     </div>
#     <svg id="myGraph_bt1"></svg>
#     <script>
#     d3.selectAll("button")
#       .on("click", function(){
#             var csvFile = this.getAttribute("csv_src1");    // data-src 속성을 읽어옴(즉, CSV 파일 이름)
#             var barElements;                               // 막대그래프의 막대 요소를 저장할 변수
#             d3.csv(csvFile,
#                 function(error, data){
#                     var dataSet = [ ];
#                     for(var i=0; i<data.length; i++){
#                            dataSet.push(data[i]["상품A"]); }
#                         barElements = d3.select("#myGraph_bt1").selectAll("rect").data(dataSet)
#                         barElements.enter().append("rect")                  // 객체 그리기 1 : 전체
#                                    .attr({"class":"bar", "height":20, "x":0,
#                                           "width": function(d, i){return d;},
#                                           "y"    : function(d, i){return i*25},})
#                         barElements.attr("width", function(d,i){return d;}) // 객체 그리기 2 : 갱신
#             });
#         });
#     </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_bt { width: 320px; height: 130px; border: 1px solid black; }
#         #myGraph_bt .bar { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 1. CSV 파일에 따른 그래프 바꾸기 </h1>
#     <div>
#         <button csv_src1="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata1.csv">mydata1.csv 불러오기</button>
#         <button csv_src1="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2.csv">mydata2.csv 불러오기</button>
#         <button csv_src1="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata3.csv">mydata3.csv 불러오기</button>
#     </div>
#     <svg id="myGraph_bt1"></svg>
#     <script>
#     d3.selectAll("button")
#       .on("click", function(){
#             var csvFile = this.getAttribute("csv_src1");    // data-src 속성을 읽어옴(즉, CSV 파일 이름)
# ...

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_bt2 { width: 320px; height: 190px; border: 1px solid black; }
#         #myGraph_bt2 .bar { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 2. CSV 컬럼이 다른 파일 그래프 그리기 </h1>
#     <div>
#         <button data-src2="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata4.csv">mydata4.csv 불러오기</button>
#         <button data-src2="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata5.csv">mydata5.csv 불러오기</button>
#         <button data-src2="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata6.csv">mydata6.csv 불러오기</button>
#     </div>
#     <svg id="myGraph_bt2"></svg>
#     <script>
#     d3.selectAll("button")
#       .on("click", function(){
#             var csvFile = this.getAttribute("data-src2");
#             var barElements;
#             d3.csv(csvFile, function(error, data){
#                      var dataSet = [ ];
#                      for(var i=0; i<data.length; i++){
#                              dataSet.push(data[i]["상품A"]); }
#                          barElements = d3.select("#myGraph_bt2").selectAll("rect").data(dataSet)
#                          barElements.enter().append("rect")
#                                     .attr({"class":"bar", "height":20, "x":0,
#                                            "y":function(d,i){return i*25}, })
#                          barElements.attr("width", function(d,i){return d;})   // 갱신(New) 객체
#                          barElements.exit().remove()                           // 기존(prototype) 삭제 (객체 전/후를 인식)
#                   });   // d3.csv 닫음
#             });         //   .on  닫음
#     </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_bt2 { width: 320px; height: 190px; border: 1px solid black; }
#         #myGraph_bt2 .bar { fill : orange; }
#     </style>
# </head>
# <body>
#     <h1> 2. CSV 컬럼이 다른 파일 그래프 그리기 </h1>
#     <div>
#         <button data-src2="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata4.csv">mydata4.csv 불러오기</button>
#         <button data-src2="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata5.csv">mydata5.csv 불러오기</button>
#         <button data-src2="https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata6.csv">mydata6.csv 불러오기</button>
#     </div>
#     <svg id="myGraph_bt2"></svg>
#     <script>
#     d3.selectAll("button")
#       .on("click", function(){
#             var csvFile = this.getAttribute("data-src2");
#             var barElements;
# ...

# %% [markdown]
# <br><br>
# ## <strong>5. 세로형 막대그래프 D3 시각화
# http://webinformation.tistory.com/36 : JavaScript 함수

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_bar { width: 320px; height: 240px; border: 1px solid black; }
#     .bar { fill : orange; }
#     .barNum {font-size: 9pt;  text-anchor : middle;}
#     .axis text {font-family: sans-serif; font-size: 11px;}
#     .axis path,
#     .axis line {fill: none; stroke: black;}
#     .axis_x line {fill: none; stroke: black;}
#     .barName {font-size: 9pt; text-anchor : middle;}
# </style>
# </head>
# <body>
#     <h1> 1. 세로형 막대그래프에 눈금 표시 </h1>
#     <svg id="myGraph_bar"></svg>
#     <script>
#     var svgHeight = 240;        // SVG 요소의 높이
#     var offsetX = 30;           // X 좌표의 오프셋(어긋남의 정도)
#     var offsetY = 20;           // Y 좌표의 오프셋(어긋남의 정도)
#     var barElements;
#     var dataSet = [120, 70, 175, 80, 220];
#
#     barElements = d3.select("#myGraph_bar").selectAll("rect").data(dataSet)
#     barElements.enter().append("rect")                              // 데이터 수만큼 rect 요소가 추가됨
#         .attr({"class":"bar", "width":20,
#                "height":function(d,i){return d;},
#                "x":function(d,i){return i * 25 + offsetX;},
#                "y":function(d,i){return svgHeight-d-offsetY;}, })
#     barElements.enter().append("text")
#         .attr({"class":"barNum",
#                "x" : function(d,i){return i * 25 + 10 + offsetX;},
#                "y" : svgHeight-5-offsetY })
#         .text(function(d,i){return d;})
#     barElements.enter().append("text")                               // 막대의 레이블을 표시
#         .attr({"class":"barName",
#                "x" : function(d,i){return i * 25 + 10 + offsetX;},   // 막대그래프의 표시 간격을 맞춤
#                "y" : svgHeight - offsetY + 15, })
#         .text(function(d, i) {return ["A","B","C","D","E"][i];})     // 레이블 이름 반환
#
#     var yScale = d3.scale.linear().domain([0, 300]).range([300, 0])  // 원래 크기, 실체 출력 크기
#     d3.select("#myGraph_bar").append("g")                            // 세로 축 눈금표시
#       .attr({"class":"axis", "transform":"translate(30,-80)"})
#       .call(d3.svg.axis().scale(yScale).orient("left"),)
#     d3.select("#myGraph_bar").append("rect")                         // 가로 축 눈금표시
#       .attr({"class":"axis_x", "width":320, "height":1,
#                "transform":"translate("+offsetX+", "+(svgHeight-offsetY)+")"})
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_bar { width: 320px; height: 240px; border: 1px solid black; }
#     .bar { fill : orange; }
#     .barNum {font-size: 9pt;  text-anchor : middle;}
#     .axis text {font-family: sans-serif; font-size: 11px;}
#     .axis path,
#     .axis line {fill: none; stroke: black;}
#     .axis_x line {fill: none; stroke: black;}
#     .barName {font-size: 9pt; text-anchor : middle;}
# </style>
# </head>
# <body>
#     <h1> 1. 세로형 막대그래프에 눈금 표시 </h1>
#     <svg id="myGraph_bar"></svg>
#     <script>
#     var svgHeight = 240;        // SVG 요소의 높이
#     var offsetX = 30;           // X 좌표의 오프셋(어긋남의 정도)
#     var offsetY = 20;           // Y 좌표의 오프셋(어긋남의 정도)
#     var barElements;
#     var dataSet = [120, 70, 175, 80, 220];
#
#     barElements = d3.select("#myGraph_bar").selectAll("rect").data(dataSet)
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_bar2 { width: 300px; height: 240px; border: 1px solid black; }
#     .bar { fill : orange; }
#     .barNum {font-size: 9pt;               text-anchor : middle;}
#     .axis text {font-family: sans-serif;   font-size: 11px;}
#     .axis path,
#     .axis line {fill: none;  stroke: black;}
#     .axis_x line {fill: none;  stroke: black;}
#     .barName {font-size: 9pt;  text-anchor : middle;}
# </style>
# </head>
# <body>
#     <h1> 2. 세로형 막대그래프 순서대로 애니메이션 효과 </h1>
#     <svg id="myGraph_bar2"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var barElements;
#     var dataSet = [120, 70, 175, 80, 220, 40, 180, 70, 90];
#     var dataMax = 300;
#     var barWidth = 20;
#     var barMargin = 5;
#
#     barElements = d3.select("#myGraph_bar2").selectAll("rect").data(dataSet)
#     barElements.enter().append("rect")
#         .attr({"class":"bar", "height":0, "width":barWidth,
#                "x":function(data,index){return index*(barWidth+barMargin) + offsetX;},
#                "y":svgHeight-offsetY,})
#         .transition().duration(1000)                // 1초동안 애니메이션 처리
#         .delay(function(d,i){return i * 100;})      // 0.1초 대기
#         .attr({"y":function(d,i){return svgHeight-d-offsetY;},
#                "height":function(d,i){return d;},}) // 애니메이션 대상 속성들
#
#     barElements.enter().append("text")              // text 요소 지정
#         .text(function(d, i){return d;})
#         .attr({"class":"barNum",  "y":svgHeight-5-offsetY,
#                "x":function(d,i){return i * (barWidth + barMargin) + 10 + offsetX;}, })
#
#     barElements.enter().append("text")              // 막대의 레이블을 표시
#         .attr({"class":"barName",
#                "x":function(d,i){return i*(barWidth + barMargin) + 10 + offsetX;}, })
#         .transition().duration(500).delay(function(d,i){return i * 150;})                  // animation 설정
#         .attr("y", svgHeight - offsetY + 15)
#         .text(function(d,i){return ["A","B","C","D","E","F","G","H","I","J","K","L"][i];}) // 레이블 이름을 반환
#
#     var yScale = d3.scale.linear().domain([0, dataMax]).range([dataMax, 0])  // 눈금표시 스케일
#     d3.select("#myGraph_bar2").append("g")                                   // 세로 축 눈금(왼쪽)
#         .call(d3.svg.axis().scale(yScale).orient("left"))
#         .attr({"class":"axis",
#                "transform":"translate("+offsetX+", "+((svgHeight-300)-offsetY)+")",})
#     d3.select("#myGraph_bar2").append("rect")                                // 가로 축 표시
#         .attr({"class":"axis_x",  "width":svgWidth, "height":1,
#                "transform":"translate("+offsetX+", "+(svgHeight-offsetY)+")"})
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_bar2 { width: 300px; height: 240px; border: 1px solid black; }
#     .bar { fill : orange; }
#     .barNum {font-size: 9pt;               text-anchor : middle;}
#     .axis text {font-family: sans-serif;   font-size: 11px;}
#     .axis path,
#     .axis line {fill: none;  stroke: black;}
#     .axis_x line {fill: none;  stroke: black;}
#     .barName {font-size: 9pt;  text-anchor : middle;}
# </style>
# </head>
# <body>
#     <h1> 2. 세로형 막대그래프 순서대로 애니메이션 효과 </h1>
#     <svg id="myGraph_bar2"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var barElements;
#     var dataSet = [120, 70, 175, 80, 220, 40, 180, 70, 90];
#     var dataMax = 300;
#     var barWidth = 20;
#     var barMargin = 5;
#
#     barElements = d3.select("#myGraph_bar2").selectAll("rect").data(dataSet)
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_bar3 { width: 320px; height: 240px; border: 1px solid black; }
#     .bar { fill : orange; }
#     .barNum {font-size: 9pt;               text-anchor : middle;}
#     .axis text {font-family: sans-serif;   font-size: 11px;}
#     .axis path,
#     .axis line {fill: none;  stroke: black;}
#     .axis_x line {fill: none;  stroke: black;}
#     .barName {font-size: 9pt;  text-anchor : middle;}
# </style>
# </head>
# <body>
#     <h1> 3. 세로형 막대그래프 애니메이션 및 마우스 효과 </h1>
#     <svg id="myGraph_bar3"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var barElements;
#     var dataSet = [120, 70, 175, 80, 220, 40, 180, 70, 90];
#     var dataMax = 300;
#     var barWidth = 20;
#     var barMargin = 5;
#
#     barElements = d3.select("#myGraph_bar3").selectAll("rect").data(dataSet)  // 그래프 그리기
#
#     barElements.enter().append("rect")
#       .attr({"class":"bar", "height":0, "width":barWidth,
#              "x":function(d,i){return i * (barWidth+barMargin)+offsetX;},
#              "y":svgHeight - offsetY,})
#       .on("mouseover", function(){d3.select(this).style("fill", "red")})
#       .on("mouseout", function(){d3.select(this).style("fill", "orange")})
#       .transition() .duration(1000).delay(function(d,i){return i * 100;})
#       .attr({"y":function(d, i){return svgHeight - d - offsetY;},
#              "height":function(d,i){return d;}, })
#
#     barElements.enter().append("text")                    // text 요소 추가
#       .attr({"class":"barNum",
#              "x" : function(d, i){return i * (barWidth+barMargin) + 10+offsetX;},
#              "y" :svgHeight - 5-offsetY, })
#       .text(function(d, i){return d;})
#
#     barElements.enter().append("text")                    // 레이블 이름을 반환
#       .attr({"class":"barName",
#              "x":function(d, i){return i * (barWidth+barMargin) + 10+offsetX;},
#              "y":svgHeight-offsetY+15,})
#       .text(function(d, i){
#         return ["A","B","C","D","E","F","G","H","I","J","K","L"][i];
#       })                                                    // 원본크기, 실체 출력 크기
#     var yScale = d3.scale.linear().domain([0, dataMax]).range([dataMax, 0])
#     d3.select("#myGraph_bar3").append("g")
#       .call(d3.svg.axis().scale(yScale).orient("left"))     // 스케일 눈금 왼쪽
#       .attr({"class":"axis",
#              "transform":"translate("+offsetX+", "+((svgHeight-300)-offsetY)+")",})
#     d3.select("#myGraph_bar3").append("rect")
#       .attr({"class":"axis_x", "width":svgWidth, "height":1,
#              "transform":"translate("+offsetX+", "+(svgHeight-offsetY)+")",})
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_bar3 { width: 320px; height: 240px; border: 1px solid black; }
#     .bar { fill : orange; }
#     .barNum {font-size: 9pt;               text-anchor : middle;}
#     .axis text {font-family: sans-serif;   font-size: 11px;}
#     .axis path,
#     .axis line {fill: none;  stroke: black;}
#     .axis_x line {fill: none;  stroke: black;}
#     .barName {font-size: 9pt;  text-anchor : middle;}
# </style>
# </head>
# <body>
#     <h1> 3. 세로형 막대그래프 애니메이션 및 마우스 효과 </h1>
#     <svg id="myGraph_bar3"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var barElements;
#     var dataSet = [120, 70, 175, 80, 220, 40, 180, 70, 90];
#     var dataMax = 300;
#     var barWidth = 20;
#     var barMargin = 5;
#
#     barElements = d3.select("#myGraph_bar3").selectAll("rect").data(dataSet)  // 그래프 그리기
#
# ...

# %%
# %%html
# <head>
#     <meta charset="utf-8">
#     <title>Sample</title>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_bar4 { width: 320px; height: 360px; border: 1px solid black; }
#         #myGraph_bar4 .bar { fill : orange; }
#         #myGraph_bar4 .barNum {font-size: 9pt; text-anchor : middle;}
#         #myGraph_bar4 .axis text {font-family: sans-serif; font-size: 11px;}
#         #myGraph_bar4 .axis path,
#         #myGraph_bar4 .axis line {fill: none; stroke: black;}
#         #myGraph_bar4 .axis_x line {fill: none; stroke: black;}
#         #myGraph_bar4 .barName {font-size: 9pt; text-anchor : middle;}
#     </style>
# </head>
# <body>
# <h1> 4. 세로형 막대그래프 애니메이션 표시</h1>
# <svg id="myGraph_bar4"></svg>
# <script>
# d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata7.csv",
#     function(error, data){
#         var dataSet = [];
#         var labelName = [];
#         for(var i in data[0]){dataSet.push(data[0][i]);   // row 1번 데이터를 추출
#                               labelName.push(i);}         // alert(JSON.stringify(dataSet))
#         var dataMax = Math.max.apply(null,dataSet);       // alert(dataMax);
#         var svgEle = document.getElementById("myGraph_bar4");
#         var svgWidth = window.getComputedStyle(svgEle, null).getPropertyValue("width");  //Template의 width CSS값을 호출
#         var svgHeight = window.getComputedStyle(svgEle, null).getPropertyValue("height");
#         svgWidth = parseFloat(svgWidth);                                          // parseFloat() 값 단위 삭제
#         svgHeight = parseFloat(svgHeight);
#
#         var offsetX = 30;
#         var offsetY = 20;
#         var barWidth = 20;
#         var barMargin = 5;
#         var barElements;
#         barElements = d3.select("#myGraph_bar4").selectAll("rect").data(dataSet) // 데이터 연결객체 정의
#         barElements.enter().append("rect")
#           .attr({"class":"bar","height":0, "width":barWidth,
#                  "x":function(d, i){return i *(barWidth+barMargin)+offsetX;},
#                  "y":svgHeight - offsetY,})
#           .on("mouseover", function(){d3.select(this).style("fill", "red")})
#           .on("mouseout", function(){d3.select(this).style("fill", "orange")})
#           .transition().duration(1000).delay(function(d,i){return i * 100;})
#           .attr({"y":function(d,i){return svgHeight-d-offsetY;},
#                  "height":function(d,i){return d;},})
#         barElements.enter().append("text")                                      // text 요소 추가
#           .text(function(d, i){return d;})
#           .attr({"class": "barNum",
#                 "x":function(d, i){return i*(barWidth+barMargin)+10+offsetX;},
#                 "y":svgHeight - 5-offsetY, }) // Y 좌표를 지정
#
#         var yScale = d3.scale.linear().domain([0, dataMax]).range([dataMax, 0])  // 눈금 표시객체
#         d3.select("#myGraph_bar4").append("g")
#           .attr({"class":"axis", "transform":"translate("+offsetX+", "+((svgHeight-300)-offsetY)+")",})
#           .call(d3.svg.axis().scale(yScale).orient("left"))
#         d3.select("#myGraph_bar4").append("rect")                                // 세로 방향의 선을 표시
#           .attr({"class": "axis_x", "width":svgWidth, "height":1,
#                 "transform":"translate("+offsetX+", "+(svgHeight-offsetY)+")",})
#
#         barElements.enter().append("text")                                      // 막대의 레이블을 표시
#           .text(function(d, i){return labelName[i];})
#           .attr({"class":"barName",
#                  "x":function(d, i){return i * (barWidth+barMargin) + 10+offsetX;},
#                  "y":svgHeight-offsetY+15,})
# });
# </script></body>
# Out:
# <head>
#     <meta charset="utf-8">
#     <title>Sample</title>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#         svg#myGraph_bar4 { width: 320px; height: 360px; border: 1px solid black; }
#         #myGraph_bar4 .bar { fill : orange; }
#         #myGraph_bar4 .barNum {font-size: 9pt; text-anchor : middle;}
#         #myGraph_bar4 .axis text {font-family: sans-serif; font-size: 11px;}
#         #myGraph_bar4 .axis path,
#         #myGraph_bar4 .axis line {fill: none; stroke: black;}
#         #myGraph_bar4 .axis_x line {fill: none; stroke: black;}
#         #myGraph_bar4 .barName {font-size: 9pt; text-anchor : middle;}
#     </style>
# </head>
# <body>
# <h1> 4. 세로형 막대그래프 애니메이션 표시</h1>
# <svg id="myGraph_bar4"></svg>
# <script>
# d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata7.csv",
#     function(error, data){
#         var dataSet = [];
#         var labelName = [];
# ...

# %% [markdown]
# <br><br>
# ## <strong>6. Pi Chart D3 시각화
# http://webinformation.tistory.com/36 : JavaScript 함수

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#   svg#myGraph_pi { width: 320px; height: 240px; border: 1px solid black; }
#   #myGraph_pi .pie { fill: orange; stroke: black; }
# </style>
# </head>
# <body>
#     <h1> 1. 원 차트 그리기 (d3 팔렛트 활용) </h1>
#     <svg id="myGraph_pi"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var dataSet = [50, 30, 12, 5, 3];                         // 데이터셋 비율(합이 100이 아니여도 됨)
#     var pie = d3.layout.pie()                                 // 원 그래프 레이아웃
#     var arc = d3.svg.arc().innerRadius(30).outerRadius(100);  // 원 그래프의 외경, 내경 설정
#     var color = d3.scale.category20();                        // d3.scale.category10() : D3.js 표준 10색
#     var pieElements = d3.select("#myGraph_pi").selectAll("path").data(pie(dataSet)) // 데이터 연결
#     pieElements.enter().append("path")                        // 데이터의 수만큼 path 요소가 추가됨
#         .attr({"class":"pie", "d":arc,                        // 부채꼴 지정 (d : Draw)
#                "transform":"translate("+svgWidth/2+", "+svgHeight/2+")",})
#         .style("fill", function(d, i){return color(i);},)	  // 표준 10색 순차적 활용
#         //.style("fill",function(d,i){return ["red","orange","yellow","cyan","#3f3"][i];},);
#     </script>
# </body>
# </html>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#   svg#myGraph_pi { width: 320px; height: 240px; border: 1px solid black; }
#   #myGraph_pi .pie { fill: orange; stroke: black; }
# </style>
# </head>
# <body>
#     <h1> 1. 원 차트 그리기 (d3 팔렛트 활용) </h1>
#     <svg id="myGraph_pi"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var dataSet = [50, 30, 12, 5, 3];                         // 데이터셋 비율(합이 100이 아니여도 됨)
#     var pie = d3.layout.pie()                                 // 원 그래프 레이아웃
#     var arc = d3.svg.arc().innerRadius(30).outerRadius(100);  // 원 그래프의 외경, 내경 설정
#     var color = d3.scale.category20();                        // d3.scale.category10() : D3.js 표준 10색
#     var pieElements = d3.select("#myGraph_pi").selectAll("path").data(pie(dataSet)) // 데이터 연결
#     pieElements.enter().append("path")                        // 데이터의 수만큼 path 요소가 추가됨
# ...

# %%
# %%html
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg#myGraph_pi2 {width: 320px; height: 240px; border: 1px solid black;}
#     #myGraph_pi2 .pie {fill: orange; stroke: white;}
#     </style>
# </head>
# <body>
# <h1> 2. 원 차트 그리기 (색인과 Animation 효과 추가)</h1>
# <svg id="myGraph_pi2"></svg>
# <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var dataSet = [50, 30, 12, 5, 3];
#     var color = d3.scale.category10();
#     var pie = d3.layout.pie().value(function(d,i){return d;})    // pi Chart 레이아웃 변수
#     var arc = d3.svg.arc().innerRadius(30).outerRadius(100)
#
#     var pieElements = d3.select("#myGraph_pi2").selectAll("g")   // 중심계산 그룹화
#           .data(pie(dataSet)).enter().append("g")
#           .attr("transform", "translate("+svgWidth/2+","+svgHeight/2+")")
#
#     pieElements.append("path").attr("class", "pie")	             // CSS 클래스 생성
#        .style("fill", function(d, i){return color(i);})
#        .transition().duration(1200)                              // Animation 효과
#        .delay(function(d,i){return i*200;}).ease("linear")       // 직선적인 움직임으로 변경
#        .attrTween("d", function(d, i){                           // 보간 처리
#             var interpolate = d3.interpolate(
#                 { startAngle : d.startAngle, endAngle : d.startAngle }, // 각 부분의 시작 각도
#                 { startAngle : d.startAngle, endAngle : d.endAngle });  // 각 부분의 종료 각도
#             return function(t){return arc(interpolate(t));} })          // 시간처리 ;} , }) 콤마는 오류가발생
#
#     pieElements.append("text")                   // 데이터 수만큼 text 요소가 추가됨
#       .attr({"class":"pieNum",                   // 부채꼴 중심 계산
#              "transform":function(d,i){return "translate("+arc.centroid(d)+")";},})
#       .text(function(d, i){return d.value;})     // 값 표시
#
#     var textElements = d3.select("#myGraph_pi2") // 합계와 문자 표시
#       .append("text").attr("class", "total")     // CSS 클래스 설정
#       .attr("transform", "translate("+svgWidth/2+", "+(svgHeight/2+5)+")")    // 중심표시
#       .text("합계:" + d3.sum(dataSet))            // 합계 표시
# </script>
# </body>
# Out:
# <head>
#     <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
#     <style>
#     svg#myGraph_pi2 {width: 320px; height: 240px; border: 1px solid black;}
#     #myGraph_pi2 .pie {fill: orange; stroke: white;}
#     </style>
# </head>
# <body>
# <h1> 2. 원 차트 그리기 (색인과 Animation 효과 추가)</h1>
# <svg id="myGraph_pi2"></svg>
# <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var dataSet = [50, 30, 12, 5, 3];
#     var color = d3.scale.category10();
#     var pie = d3.layout.pie().value(function(d,i){return d;})    // pi Chart 레이아웃 변수
#     var arc = d3.svg.arc().innerRadius(30).outerRadius(100)
#
#     var pieElements = d3.select("#myGraph_pi2").selectAll("g")   // 중심계산 그룹화
#           .data(pie(dataSet)).enter().append("g")
#           .attr("transform", "translate("+svgWidth/2+","+svgHeight/2+")")
#
#     pieElements.append("path").attr("class", "pie")	             // CSS 클래스 생성
#        .style("fill", function(d, i){return color(i);})
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_pi3 { width: 320px; height: 240px; border: 1px solid black; }
#     #myGraph_pi3 .pie { fill: orange; stroke: white; }
#     #myGraph_pi3 .total { font-size: 8pt; text-anchor: middle; }
#     #myGraph_pi3 .pieNum { font-size: 15pt; color: white; text-anchor: middle; }
# </style>
# </head>
# <body>
# <h1> 3. 연도별 원 차트 그리기 </h1>
# <svg id="myGraph_pi3"></svg>
# <form>
# <select id="year">
#     <option value="2008">2008년</option> <option value="2009">2009년</option>
#     <option value="2010">2010년</option> <option value="2011">2011년</option>
#     <option value="2012">2012년</option> <option value="2013">2013년</option>
#     <option value="2014">2014년</option>
# </select>
# </form>
# <script>
# drawPie("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2008.csv"); //최초 데이터
# d3.select("#year").on("change", function(){
#     d3.select("#myGraph_pi3").selectAll("*").remove();         // 메모리 저장 된 SVG 삭제
#     drawPie("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata"+
#             this.value+".csv", this.value); });	               // 연도별 객체 특정
#
# function drawPie(filename){ d3.csv(filename, function(error, data){
#     var dataSet = [ ];
#     for(var i in data[0]){dataSet.push(data[0][i]);}
#         var svgEle = document.getElementById("myGraph_pi3");   // SVG 요소의 넓이와 높이를 구함
#         var svgWidth = window.getComputedStyle(svgEle, null).getPropertyValue("width");
#         var svgHeight = window.getComputedStyle(svgEle, null).getPropertyValue("height");
#         svgWidth = parseFloat(svgWidth);
#         svgHeight = parseFloat(svgHeight);
#         var color = d3.scale.category10();
#         var pie = d3.layout.pie()                              // 원 그래프 좌표 객체
#         var arc = d3.svg.arc().innerRadius(30).outerRadius(100)
#         var pieElements = d3.select("#myGraph_pi3")            // 원 중심 그리기 객체
#             .selectAll("g").data(pie(dataSet)).enter().append("g")
#             .attr("transform", "translate("+svgWidth/2+", "+svgHeight/2+")")
#
#         pieElements.append("path").attr("class", "pie")
#             .style("fill", function(d, i){return color(i);},)  // 표준 10색 순차적 활용
#             .transition().duration(200).delay(function(d,i){return i*200;})
#             .ease("linear")
#             .attrTween("d", function(d, i){	                   // 보간 처리
#                 var interpolate = d3.interpolate(
#                     { startAngle : d.startAngle, endAngle : d.startAngle },
#                     { startAngle : d.startAngle, endAngle : d.endAngle }, );
#                 return function(t){return arc(interpolate(t));}  // 시간처리
#                 })
#
#         var textElements = d3.select("#myGraph").append("text").attr("class", "total")
#           .attr("transform", "translate("+svgWidth/2+", "+(svgHeight/2+5)+")").text("점유율")
#
#         pieElements.append("text").attr("class", "pieNum")
#           .attr("transform", function(d, i){return "translate("+arc.centroid(d)+")";})
#           .text(function(d, i){return d.value;})
#         });
#     }
# </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_pi3 { width: 320px; height: 240px; border: 1px solid black; }
#     #myGraph_pi3 .pie { fill: orange; stroke: white; }
#     #myGraph_pi3 .total { font-size: 8pt; text-anchor: middle; }
#     #myGraph_pi3 .pieNum { font-size: 15pt; color: white; text-anchor: middle; }
# </style>
# </head>
# <body>
# <h1> 3. 연도별 원 차트 그리기 </h1>
# <svg id="myGraph_pi3"></svg>
# <form>
# <select id="year">
#     <option value="2008">2008년</option> <option value="2009">2009년</option>
#     <option value="2010">2010년</option> <option value="2011">2011년</option>
#     <option value="2012">2012년</option> <option value="2013">2013년</option>
#     <option value="2014">2014년</option>
# </select>
# </form>
# <script>
# drawPie("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2008.csv"); //최초 데이터
# d3.select("#year").on("change", function(){
# ...

# %% [markdown]
# <br><br>
# ## <strong>7. Line Chart D3 시각화
# http://webinformation.tistory.com/36 : JavaScript 함수

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_line {width: 380px; height: 240px; border: 1px solid black;}
#     #myGraph_line .line {fill: none; stroke: black;}
#     #myGraph_line .axis text {font-family: sans-serif; font-size: 11px;}
#     #myGraph_line .axis path,
#     #myGraph_line .axis line {fill: none; stroke: black;}
#     #myGraph_line .axis_x line {fill: none; stroke: black;}
#     #myGraph_line .itemA {stroke: #000;}
#     #myGraph_line .itemB {stroke: #666;}
#     #myGraph_line .itemC {stroke: #ccc;}
# </style>
# </head>
# <body>
#     <h1> 1. 꺽은선 그래프 D3 시각화 </h1>
#     <svg id="myGraph_line"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var scale = 2.0;
#     var dataSet1 = [10, 47, 65, 8, 64, 99, 75, 22, 63, 80];
#     var dataSet2 = [90, 77, 55, 48, 64, 90, 85, 42, 13, 40];
#     var dataSet3 = [50, 27, 45, 58, 84, 70, 45, 22, 30, 90];
#     var margin = svgWidth / (dataSet1.length - 1);  // 꺾은선 그래프의 간격 계산
#     drawGraph(dataSet1, "itemA", "red");            // itemA의 꺾은선을 함수로 그리기
#     drawGraph(dataSet2, "itemB", "green");
#     drawGraph(dataSet3, "itemC", "magenta");
#     drawScale();
#
#     function drawGraph(dataSet, cssClassName, color) {                  // 꺾은선 표시함수
#         var line = d3.svg.line()
#             .x(function(d, i) {return offsetX+i*margin;})               // X축 순서×간격
#             .y(function(d, i) {return svgHeight-(d*scale)-offsetY;})    // 데이터로부터 Y 좌표 빼기
#
#         var lineElements = d3.select("#myGraph_line").append("path")     // 꺾은선 그래프 그리기
#             .attr({"style":"stroke:"+color, "class":"line " + cssClassName,
#                    "d":line(dataSet)}) //연속선 지정
#         }
#
#     function drawScale(){var yScale =
#         d3.scale.linear().domain([0, 100]).range([scale * 100, 0])       // 스케일 표시
#         d3.select("#myGraph_line").append("g").attr("class", "axis")     // 세로 축 눈금 표시(왼쪽)
#             .attr("transform", "translate(" + offsetX + ", " + offsetY + ")")
#             .call(d3.svg.axis().scale(yScale).orient("left"))
#         d3.select("#myGraph_line").append("rect")                        // 가로 축 표시
#             .attr({"class":"axis_x", "width":svgWidth, "height":1,
#                    "transform":"translate("+offsetX+", "+(svgHeight-offsetY-0.5)+")"})
#         }
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_line {width: 380px; height: 240px; border: 1px solid black;}
#     #myGraph_line .line {fill: none; stroke: black;}
#     #myGraph_line .axis text {font-family: sans-serif; font-size: 11px;}
#     #myGraph_line .axis path,
#     #myGraph_line .axis line {fill: none; stroke: black;}
#     #myGraph_line .axis_x line {fill: none; stroke: black;}
#     #myGraph_line .itemA {stroke: #000;}
#     #myGraph_line .itemB {stroke: #666;}
#     #myGraph_line .itemC {stroke: #ccc;}
# </style>
# </head>
# <body>
#     <h1> 1. 꺽은선 그래프 D3 시각화 </h1>
#     <svg id="myGraph_line"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var scale = 2.0;
#     var dataSet1 = [10, 47, 65, 8, 64, 99, 75, 22, 63, 80];
#     var dataSet2 = [90, 77, 55, 48, 64, 90, 85, 42, 13, 40];
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg {width: 380px; height: 240px; border: 1px solid black;}
#     .line {fill: none; stroke: black;}
#     .axis text {font-family: sans-serif; font-size: 11px;}
#     .axis path,
#     .axis line {fill: none; stroke: black;}
#     .axis_x line {fill: none; stroke: black;}
#     .itemA {stroke: #000;}
#     .itemB {stroke: #666;}
#     .itemC {stroke: #ccc;}
# </style>
# </head>
# <body>
#     <h1> 2. 꺾은선 그래프의 보간법 적용 </h1>
#     <svg id="myGraph_line2"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var scale = 2.0;
#     var dataSet1 = [10, 47, 65, 8, 64, 99, 75, 22, 63, 80];
#     var dataSet2 = [90, 77, 55, 48, 64, 90, 85, 42, 13, 40];
#     var dataSet3 = [50, 27, 45, 58, 84, 70, 45, 22, 30, 90];
#     var margin = svgWidth /(dataSet1.length - 1); // 꺾은선 그래프의 간격 계산
#     drawGraph(dataSet1, "itemA", "linear");       // 보간1 : 직선
#     drawGraph(dataSet2, "itemB", "basis");        // 보간2 : 곡선
#     drawGraph(dataSet3, "itemC", "step");         // 보간3 : 계단
#     drawScale();                                  // 눈금표시
#
#     function drawGraph(dataSet, cssClassName, type){    // 꺾은선 모양을 설정
#         var line = d3.svg.line().interpolate(type)
#             .x(function(d, i){return offsetX+i*margin;})
#             .y(function(d, i){return svgHeight-(d*scale)-offsetY;})
#         var lineElements = d3.select("#myGraph_line2")   // 꺾은선 그래프 그리기
#             .append("path").attr({"class":"line "+cssClassName,
#                                   "d":line(dataSet)})  }
#
#     function drawScale(){var yScale = d3.scale
#         .linear().domain([0, 100]).range([scale*100, 0]) // 눈금 표시 : g 추가
#         d3.select("#myGraph_line2").append("g")
#           .attr({"class":"axis", "transform":"translate("+offsetX+", "+offsetY+")"})
#           .call(d3.svg.axis().scale(yScale).orient("left"))
#         d3.select("#myGraph_line2").append("rect")
#           .attr({"class":"axis_x", "width":svgWidth, "height":1,
#                  "transform":"translate("+offsetX+", "+(svgHeight-offsetY-0.5)+")"})  }
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg {width: 380px; height: 240px; border: 1px solid black;}
#     .line {fill: none; stroke: black;}
#     .axis text {font-family: sans-serif; font-size: 11px;}
#     .axis path,
#     .axis line {fill: none; stroke: black;}
#     .axis_x line {fill: none; stroke: black;}
#     .itemA {stroke: #000;}
#     .itemB {stroke: #666;}
#     .itemC {stroke: #ccc;}
# </style>
# </head>
# <body>
#     <h1> 2. 꺾은선 그래프의 보간법 적용 </h1>
#     <svg id="myGraph_line2"></svg>
#     <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var scale = 2.0;
#     var dataSet1 = [10, 47, 65, 8, 64, 99, 75, 22, 63, 80];
#     var dataSet2 = [90, 77, 55, 48, 64, 90, 85, 42, 13, 40];
#     var dataSet3 = [50, 27, 45, 58, 84, 70, 45, 22, 30, 90];
#     var margin = svgWidth /(dataSet1.length - 1); // 꺾은선 그래프의 간격 계산
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_line3 { width: 380px; height: 300px; border: 1px solid black; }
#     #myGraph_line3 .line { fill: none; stroke: black; }
#     #myGraph_line3 .axis text {font-family: sans-serif; font-size: 11px;}
#     #myGraph_line3 .axis path,
#     #myGraph_line3 .axis line {fill: none; stroke: black;}
#     #myGraph_line3 .itemA { stroke: #000; }
#     #myGraph_line3 .itemB { stroke: #666; }
#     #myGraph_line3 .itemC { stroke: #ccc; }
# </style>
# </head>
# <body>
#     <h1> 3. Ajax를 적용한 꺾은선 그래프 </h1>
#     <svg id="myGraph_line3"></svg>
#     <div>
#         <button id="prev">이전</button>
#         <button id="next">다음</button>
#     </div>
# <script>
# d3.json("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2.json",
#     function(error, data){
#         var dataSet = [ ];
#         var svgEle  = document.getElementById("myGraph_line3");
#         var svgWidth  = window.getComputedStyle(svgEle, null).getPropertyValue("width");
#         var svgHeight = window.getComputedStyle(svgEle, null).getPropertyValue("height");
#         svgWidth  = parseFloat(svgWidth)  - 60;
#         svgHeight = parseFloat(svgHeight) - 60;
#         var offsetX   = 30;
#         var offsetY   = 20;
#         var scale     = 2.0;
#         var rangeYear = 10;                     // 10년 데이터를 표시
#         var year = d3.extent(data, function(d){return d.year;}); // 최대,최소 연도
#         var startYear   = year[0];              // 최초 연도
#         var currentYear = 2000;                 // 최초의 표시 기준 연도
#         var margin = svgWidth /(rangeYear - 1);	// 꺾은선 그래프의 간격 계산
#
#         pickupData(data, currentYear-startYear);        // 표시 범위의 데이터를 입력
#         drawGraph(dataSet, "item1", "itemA", "linear"); // item1의 데이터 그리기
#         drawGraph(dataSet, "item2", "itemB", "linear");
#         drawGraph(dataSet, "item3", "itemC", "linear");
#         drawScale();                                    // 눈금 표시
#
#         function drawGraph(dataSet, itemName, cssClassName, type){   // 꺾은선 그래프의 좌표를 계산하는 메서드
#             var line = d3.svg.line().interpolate(type)               // svg의 선
#                 .x(function(d, i){return offsetX+i*margin;})
#                 .y(function(d, i){return svgHeight-(d[itemName]*scale)-offsetY;})
#             var lineElements = d3.select("#myGraph_line3").append("path")
#                 .attr({"class":"line "+cssClassName, "d":line(dataSet)})   }
#
#         function drawScale(){var yScale = d3.scale.linear()          // 그래프 눈금표시
#               .domain([0, 100]).range([scale*100, 0])
#
#         d3.select("#myGraph_line3").append("g")
#           .call(d3.svg.axis().scale(yScale).orient("left"))
#           .attr({"class":"axis",
#                  "transform":"translate("+offsetX+", "+((100-(scale-1)*100)+offsetY)+")"})
#
#         var xScale = d3.time.scale().domain([new Date(currentYear+"/1/1"),     // 가로 눈금표시
#             new Date((currentYear+rangeYear-1)+"/1/1")]).range([0,svgWidth])   // 연도표시 크기
#
#         d3.select("#myGraph_line3").append("g")	                               // 가로 눈금 표시
#           .attr({"class":"axis", "transform":"translate("+offsetX+", "+(svgHeight - offsetY)+")"})
#           .call(d3.svg.axis().scale(xScale).orient("bottom").ticks(10)	       // 1년마다 표시
#                   .tickFormat(function(d, i){
#                         var fmtFunc = d3.time.format("%Y년%m월");               // 연도,월 표시방법
#                         return fmtFunc(d); }))
#           .selectAll("text")
#           .attr({"transform":"rotate(90)",  "dx":"0.7em",  "dy":"-0.4em"})
#           .style("text-anchor", "start")  // 표시 위치 지정
#         }
#
#     function pickupData(data, start){ 	                        // JSON 데이터셋을 추출 후 SVG 삭제
#         dataSet = [ ];                                          // 데이터셋 삭제
#         for(var i=0; i<rangeYear; i++){dataSet[i] = data[start + i];}
#         d3.select("#myGraph_line3").selectAll("*").remove(); }  // SVG 메모리 삭제
#
#     d3.select("#prev").on("click", function(){                   // <이전> 버튼에 이벤트를 할당
#         if (currentYear > year[0]){currentYear = currentYear-1;} // 최소연도 클 때, 연도를 1 감소
#         pickupData(data, currentYear-startYear);	// 표시 범위의 데이터를 입력
#         drawGraph(dataSet, "item1", "itemA", "linear");
#         drawGraph(dataSet, "item2", "itemB", "linear");
#         drawGraph(dataSet, "item3", "itemC", "linear");
#         drawScale();  })
#
#     d3.select("#next").on("click", function(){                   // <다음> 버튼에 이벤트를 할당
#         if (currentYear <= year[1]-rangeYear){currentYear = currentYear + 1;} // 최대연도보다 작으면 1 증가
#         pickupData(data, currentYear-startYear);                 // 표시 범위의 데이터를 입력
#         drawGraph(dataSet, "item1", "itemA", "linear");
#         drawGraph(dataSet, "item2", "itemB", "linear");
#         drawGraph(dataSet, "item3", "itemC", "linear");
#         drawScale(); });
# });
# </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_line3 { width: 380px; height: 300px; border: 1px solid black; }
#     #myGraph_line3 .line { fill: none; stroke: black; }
#     #myGraph_line3 .axis text {font-family: sans-serif; font-size: 11px;}
#     #myGraph_line3 .axis path,
#     #myGraph_line3 .axis line {fill: none; stroke: black;}
#     #myGraph_line3 .itemA { stroke: #000; }
#     #myGraph_line3 .itemB { stroke: #666; }
#     #myGraph_line3 .itemC { stroke: #ccc; }
# </style>
# </head>
# <body>
#     <h1> 3. Ajax를 적용한 꺾은선 그래프 </h1>
#     <svg id="myGraph_line3"></svg>
#     <div>
#         <button id="prev">이전</button>
#         <button id="next">다음</button>
#     </div>
# <script>
# d3.json("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata2.json",
#     function(error, data){
#         var dataSet = [ ];
#         var svgEle  = document.getElementById("myGraph_line3");
# ...

# %% [markdown]
# <br><br>
# ## <strong>8. Scatter Chart D3 시각화
# http://webinformation.tistory.com/36 : JavaScript 함수

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_st { width: 380px; height: 240px; border: 1px solid black; }
#     #myGraph_st .mark { fill: red; stroke: none; }
# </style>
# </head>
# <body>
# <h1> 1. 산포도에 애니메이션 표시 </h1>
# <svg id="myGraph_st"></svg>
# <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var dataSet = [ [30, 40], [120, 115], [125, 90], [150, 160], [300, 190],
#                     [60, 40], [140, 145], [165, 110], [200, 170], [250, 190] ];
#     var circleElements = d3.select("#myGraph_st")
#         .selectAll("circle").data(dataSet).enter().append("circle")
#         .attr({"class":"mark", "r":5,
#                "cx" : function(d, i){return d[0];},
#                "cy" : function(d, i){return svgHeight-d[1];}, })
#
#     function updateData(data){
#         var result = data.map(function(d, i){
#             var x = Math.random() * svgWidth;   // 0 ~ 1 사의의 난수를 더해줌
#             var y = Math.random() * svgHeight;
#             return [x, y];})
#         return result;}
#
#     function updateGraph(){
#         circleElements.data(dataSet).transition()	// cx, cy 애니메이션
#                       .attr({"cx":function(d, i){return d[0];},
#                              "cy":function(d, i){return svgHeight-d[1];} })  }
#
#     setInterval(function(){             // 타이머 2초 갱신
#         dataSet = updateData(dataSet);  // 데이터 갱신
#         updateGraph();}, 2000);
# </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_st { width: 380px; height: 240px; border: 1px solid black; }
#     #myGraph_st .mark { fill: red; stroke: none; }
# </style>
# </head>
# <body>
# <h1> 1. 산포도에 애니메이션 표시 </h1>
# <svg id="myGraph_st"></svg>
# <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var dataSet = [ [30, 40], [120, 115], [125, 90], [150, 160], [300, 190],
#                     [60, 40], [140, 145], [165, 110], [200, 170], [250, 190] ];
#     var circleElements = d3.select("#myGraph_st")
#         .selectAll("circle").data(dataSet).enter().append("circle")
#         .attr({"class":"mark", "r":5,
#                "cx" : function(d, i){return d[0];},
#                "cy" : function(d, i){return svgHeight-d[1];}, })
#
#     function updateData(data){
#         var result = data.map(function(d, i){
#             var x = Math.random() * svgWidth;   // 0 ~ 1 사의의 난수를 더해줌
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_st1 { width: 380px; height: 240px; border: 1px solid black; }
#     #myGraph_st1 .mark { fill: red; stroke: none; }
#     #myGraph_st1 .axis text {font-family: sans-serif; font-size: 11px;}
#     #myGraph_st1 .axis path,
#     #myGraph_st1 .axis line {fill: none; stroke: black;}
# </style>
# </head>
# <body>
# <h1> 2. 산포도에 애니메이션 눈금 표시 </h1>
# <svg id="myGraph_st1"></svg>
# <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var dataSet = [ [30, 40], [120, 115], [125, 90], [150, 160], [300, 170],
#                    [60, 40], [140, 145], [165, 110], [200, 170], [250, 160] ];
#
#     var circleElements = d3.select("#myGraph_st1")   // 산포도 그리기
#         .selectAll("circle").data(dataSet).enter().append("circle")
#         .attr({"class":"mark", "r":5,
#                "cx":function(d,i){return d[0]+offsetX;},
#                "cy":function(d,i){return svgHeight-d[1]-offsetY;} })
#
#     function updateData(data){var result = data.map( // 좌표값을 배열로 반환
#         function(d, i){var x = Math.random() * svgWidth;
#                        var y = Math.random() * svgHeight;
#             return [x, y];})
#             return result;}                          // return 객체는 줄바꿈을 해야한다
#
#     function updateGraph(){circleElements.data(dataSet).transition()        // 산포도 갱신
#         .attr({"cx":function(d,i){return d[0]+offsetX;},
#                "cy":function(d,i){return svgHeight-d[1]-offsetY;} }) }
#
#     function drawScale(){d3.select("#myGraph_st1").selectAll("g").remove(); // 눈금 요소 삭제
#         var maxX = d3.max(dataSet, function(d, i){return d[0];});
#         var maxY = d3.max(dataSet, function(d, i){return d[1];});
#         var yScale = d3.scale.linear().domain([0, maxY]).range([maxY, 0])
#         d3.select("#myGraph_st1").append("g")
#           .call(d3.svg.axis().scale(yScale).orient("left"))
#           .attr({"class":"axis", "transform":"translate("+offsetX+", "+(svgHeight-maxY-offsetY)+")",})
#         var xScale = d3.scale.linear().domain([0, maxX]).range([0, maxX])
#         d3.select("#myGraph_st1").append("g")
#           .attr({"class":"axis","transform":"translate("+offsetX+", "+(svgHeight-offsetY)+")"})
#           .call(d3.svg.axis().scale(xScale).orient("bottom"))   }
#
#     drawScale();
#     setInterval(function(){dataSet = updateData(dataSet);
#                                      drawScale();
#                                      updateGraph();}, 2000);
# </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_st1 { width: 380px; height: 240px; border: 1px solid black; }
#     #myGraph_st1 .mark { fill: red; stroke: none; }
#     #myGraph_st1 .axis text {font-family: sans-serif; font-size: 11px;}
#     #myGraph_st1 .axis path,
#     #myGraph_st1 .axis line {fill: none; stroke: black;}
# </style>
# </head>
# <body>
# <h1> 2. 산포도에 애니메이션 눈금 표시 </h1>
# <svg id="myGraph_st1"></svg>
# <script>
#     var svgWidth = 320;
#     var svgHeight = 240;
#     var offsetX = 30;
#     var offsetY = 20;
#     var dataSet = [ [30, 40], [120, 115], [125, 90], [150, 160], [300, 170],
#                    [60, 40], [140, 145], [165, 110], [200, 170], [250, 160] ];
#
#     var circleElements = d3.select("#myGraph_st1")   // 산포도 그리기
#         .selectAll("circle").data(dataSet).enter().append("circle")
#         .attr({"class":"mark", "r":5,
#                "cx":function(d,i){return d[0]+offsetX;},
# ...

# %%
# %%html
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_st2 { width: 380px; height: 300px; border: 1px solid black; }
#     #myGraph_st2 .mark { fill: red; stroke: none; }
#     #myGraph_st2 .axis text {font-family: sans-serif;font-size: 11px;}
#     #myGraph_st2 .axis path,
#     #myGraph_st2 .axis line {fill: none; stroke: black;}
#     #myGraph_st2 .grid {stroke:gray; stroke-dasharray:4,2; shape-rendering:crispEdges;}
#     #myGraph_st2 .tip {position:absolute; top:0px; left:0px; z-index:9999;
#         visibility:hidden; border: 1px solid black; background-color: yellow;
#         width: 80px; height: 16px; overflow : hidden; text-align : center;
#         font-size: 9pt; font-family : Tahoma, Optima, Helvetica; color: black;}
# </style>
# </head>
# <body>
# <h1>산포도 표시</h1>
#     <svg id="myGraph_st2"></svg>
#     <script>
#     d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata8.csv",
#         function(error, data){                                    // CSV 데이터를 불러옴
#             var svgEle = document.getElementById("myGraph_st2");
#             var svgWidth = window.getComputedStyle(svgEle, null).getPropertyValue("width");
#             var svgHeight = window.getComputedStyle(svgEle, null).getPropertyValue("height");
#             svgWidth = parseFloat(svgWidth);
#             svgHeight = parseFloat(svgHeight);
#             var offsetX = 30;
#             var offsetY = 20;
#             var svg = d3.select("#myGraph_st2");
#             var dataSet = [ ];
#             data.forEach(function(d, i){
#                 dataSet.push([d.total/100, d.bug*1, d.time*1]);	  // *1로 숫자 변환
#             });
#         var circleElements = svg.selectAll("circle").data(dataSet) // 데이터셋 설정
#         circleElements.enter().append("circle")
#             .attr({"class":"mark", "r":100, "opacity":0,           // 0(투명) ~ 1(진함)
#                    "cx":svgWidth/2+offsetX, "cy":svgHeight/2-offsetY})
#             .transition().duration(2000).ease("bounce")            // 튀는 움직임
#             .attr({"cx" : function(d, i){return d[0] + offsetX;},
#                    "cy" : function(d, i){return svgHeight-d[1]-offsetY;},
#                    "r"  : 6, "opacity" : 1.0 })
#
#         function drawScale(){var maxX = d3.max(dataSet,
#             function(d, i){return d[0];});
#             var maxY = d3.max(dataSet, function(d, i){return d[1];});
#             var yScale = d3.scale.linear().domain([0, maxY]).range([maxY, 0]);
#             svg.append("g")
#                .call(d3.svg.axis().scale(yScale).orient("left"))
#                .attr({"class":"axis", "transform":"translate("+offsetX+", "+(svgHeight-maxY-offsetY)+")"})
#
#         var xScale = d3.scale.linear().domain([0, maxX]).range([0, maxX]) // 실제 눈금 표시
#             svg.append("g")	                                              // g 요소 추가. 이것이 눈금을 표시하는 요소가 됨
#               .attr({"class":"axis", "transform":"translate("+offsetX+", "+(svgHeight-offsetY)+")"})
#               .call(d3.svg.axis().scale(xScale).orient("bottom"))
#             var grid = svg.append("g");
#             var rangeX = d3.range(50, maxX, 50);
#             var rangeY = d3.range(20, maxY, 20);
#             grid.selectAll("line.y").data(rangeY).enter().append("line")   // line 요소 추가
#                 .attr({"class":"grid", "x1":offsetX, "x2":maxX+offsetX ,
#                        "y1":function(d, i){return svgHeight-d-offsetY;} ,
#                        "y2":function(d,i){return svgHeight-d-offsetY;} })
#             grid.selectAll("line.x").data(rangeX).enter().append("line")	// line요소의 x 클래스를 선택
#                 .attr({"class":"grid", "x1":function(d,i){return d + offsetX;},
#                        "y1":svgHeight - offsetY, "x2":function(d,i){return d + offsetX;},
#                        "y2":svgHeight -offsetY - maxY})
#             }
#         var tooltip = d3.select("body").append("div").attr("class", "tip")  // 풍선 도움말을 생성
#         circleElements
#             .on("mouseover", function(d){
#                     var x = parseInt(d[0]);
#                     var y = parseInt(d[1]);
#                     var data = d3.select(this).datum();
#                     var t = parseInt(data[2]);
#                     tooltip.style({"left" : offsetX + x+"px",
#                                    "top"  : svgHeight + offsetY - y+"px",
#                                    "visibility" : "visible"})                   // 풍선 도움말 표시
#                            .text(t+"시간") })
#             .on("mouseout", function(){tooltip.style("visibility", "hidden")})  // 풍선 도움말을 숨김
#         drawScale();   // 눈금과 그리드를 표시
#     });
#     </script>
# </body>
# Out:
# <head>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <style>
#     svg#myGraph_st2 { width: 380px; height: 300px; border: 1px solid black; }
#     #myGraph_st2 .mark { fill: red; stroke: none; }
#     #myGraph_st2 .axis text {font-family: sans-serif;font-size: 11px;}
#     #myGraph_st2 .axis path,
#     #myGraph_st2 .axis line {fill: none; stroke: black;}
#     #myGraph_st2 .grid {stroke:gray; stroke-dasharray:4,2; shape-rendering:crispEdges;}
#     #myGraph_st2 .tip {position:absolute; top:0px; left:0px; z-index:9999;
#         visibility:hidden; border: 1px solid black; background-color: yellow;
#         width: 80px; height: 16px; overflow : hidden; text-align : center;
#         font-size: 9pt; font-family : Tahoma, Optima, Helvetica; color: black;}
# </style>
# </head>
# <body>
# <h1>산포도 표시</h1>
#     <svg id="myGraph_st2"></svg>
#     <script>
#     d3.csv("https://raw.githubusercontent.com/YongBeomKim/Tutorials/master/Web/data/mydata8.csv",
# ...

# %% [markdown]
# <br><br>
# ## <strong>9. Histogram Chart D3 시각화
# http://webinformation.tistory.com/36 : JavaScript 함수
