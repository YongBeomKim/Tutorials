# %%
# 파이썬 라이브러리를 이용한 데이터 분석 
# https://play.dobest.io / ID : tacademy / Pass : dkstncks

# 크레딧잡 
# https://kreditjob.com/

# 함수 
# "삼성" => 모든 삼성 계열사 ( 삼성SDS, 삼성전자 )

# %%
# 2. 동적인 사이트! 서버로부터 데이터를 받아온다!
# 크롬 개발자 도구 > Network > All

# 실제 매물정보(리소스)를 가지고 있는 API 를 찾자.

# %%
# ALL => Image, CSS, JS, XHR,...

# AJAX ( Async Javascript and XML ) - XML HTTP Request ( XHR )
# 서버로 부터 데이터를 받아오는(Fetch)

# %%
url = "https://api.zigbang.com/v1/items?detail=true&item_ids=6423394&item_ids=6395815&item_ids=5995433&item_ids=6424758&item_ids=6211301&item_ids=6285114&item_ids=6426548&item_ids=6410702&item_ids=6305853&item_ids=6256852&item_ids=6396121&item_ids=6424508&item_ids=6393377&item_ids=6415633&item_ids=6338386&item_ids=6422447&item_ids=6167680&item_ids=6424804&item_ids=6400219&item_ids=6235949&item_ids=6312690&item_ids=6394232&item_ids=6188763&item_ids=6289652&item_ids=6389364&item_ids=6425232&item_ids=6323511&item_ids=6322440&item_ids=6254050&item_ids=6339438&item_ids=6398176&item_ids=6254961&item_ids=6124173&item_ids=6387858&item_ids=6322281&item_ids=6421010&item_ids=6238499&item_ids=6367887&item_ids=6354071&item_ids=6417467&item_ids=6427351&item_ids=6425246&item_ids=6424318&item_ids=6335211&item_ids=6113664&item_ids=6275936&item_ids=6413574&item_ids=6384007&item_ids=6222912&item_ids=6422507&item_ids=6293543&item_ids=6405725&item_ids=6413261&item_ids=6424746&item_ids=6350223&item_ids=6401349&item_ids=6390306&item_ids=6276404&item_ids=6323525&item_ids=6394144"

# %%
import requests

# %%
response = requests.get(url)

# %%
# response.text  # JSON Format 으로 만들어진 Str
# ========================================> Dict
# 플러그인명: JSONView
# --------------
# 1. [  {"deposit": ___, "rent": ______}, {...} ]
# 2. 연산: 매물의 보증금 합! ( 월세의 합 )

# %%
import json

# %%
# data = json.loads(response.text)
data = response.json()

# %%
data.get("items")[1].get("item").get("rent")
#                 2,3,4
# Out:
# 0

# %%
data = response.json()
data = [
    item.get("item")
    for item
    in data.get("items")
]
data = [
    {
        "deposit": item.get("deposit"),
        "rent": item.get("rent"),
    }
    for item
    in data
]

# %%
len(data)
# Out:
# 49

# %%
from functools import reduce

# %%
deposit_rent_sum = reduce(
    lambda a, b: {
        "deposit": a["deposit"] + b["deposit"],
        "rent": a["rent"] + b["rent"],
    },
    data,
)

# %%
deposit_rent_sum["deposit"] / len(data)
# Out:
# 5867.34693877551

# %%
deposit_rent_sum["rent"] / len(data)
# Out:
# 26.244897959183675

# %%
# .sum()
# .mean()

# %%
# 서비스 개발자 입장에서,

# 0. 로그인 ( 쿠키, 세션 ) / Authorization
# 1. Host, Referer
# 2. Custom Header

# 요기요 -> 모바일(API), 웹 
#         Basic Auth, JWT, Token-based Auth

# ---
# API Client ( Postman . getpostman.com )

# %%
import requests
url = "https://www.yogiyo.co.kr/api/v1/restaurants-geo/?items=20&order=rank&page=0&search=&zip_code=151057"

# %%
headers = {
    "X-ApiKey": "iphoneap",
    "X-ApiSecret": "fe5183cc3dea12bd0ce299cf110a75a2"
}
# Network 탭에서 직접 찾아보세요!

# %%
response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# {'pagination': {'current_page': 0,
#   'per_page': 20,
#   'total_objects': 304,
#   'total_pages': 16},
#  'restaurants': [{'additional_discount': 2000,
#    'additional_discount_currently_active': True,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1643-5 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.0167376472982876,
#    'except_cash': False,
#    'franchise_id': 37,
#    'franchise_name': '(유)비에이치씨 / BHC치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 218087,
#    'is_hotdeal': True,
#    'keywords': 'BHC-낙성대점 <후라이드> 쏘스에무쵸 <후라이드> 쏘스에무쵸HOT <양념／순살> 치킨강정 <후라이드> 별코치（별에서온코스치킨） <콜라／무／소스> 커리딥소스 <콜팝> 콜팝치킨 <양념／순살> 순살치킨강정 <콜라／무／소스> 뿌링뿌링소스 <콜팝> 미니콜팝 <뿌링클> 바삭클',
#    'lat': 37.4740522999295,
#    'list_pos': 1,
#    'lng': 126.9680474,
#    'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_uetXCQA.JPG',
#    'loyal_score': 15.9383967252744,
#    'min_order_amount': 15000,
#    'name': 'BHC-낙성대점',
#    'new': False,
#    'new_rating': 1.0341883395513185,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 23:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352576215',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200035.341442411,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 4.575,
#    'review_count': 200,
#    'review_image_count': 46,
#    'section': 'hotdeal',
#    'section_pos': 1,
#    'slug': 'bhc치킨-낙성대점',
#    'sms_bonus': True,
#    'subtitle': '',
#    'tags': ['CESCO'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1598-2',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '분식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.3963104888636524,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 10476,
#    'is_hotdeal': False,
#    'keywords': '라티놀 안주류 오뎅탕 세트메뉴 세트3（콩라면＋크런치롤반줄） 안주류 계란찜 세트메뉴 세트5（해물라면＋크런치롤반줄） 면류 가쓰오해물우동 세트메뉴 세트4（콩라면＋참치김밥반줄） 안주류 매운양념닭발 세트메뉴 세트9（가쓰오우동＋크런치롤반줄） 분식류 치즈라볶이（2인분） 계절메뉴 사골떡국',
#    'lat': 37.4789635,
#    'list_pos': 2,
#    'lng': 126.9528282,
#    'logo_url': '/media/restaurant_logos/라티놀_20140822_가맹로고_crop_200x200.jpg',
#    'loyal_score': 27.0620260195168,
#    'min_order_amount': 10000,
#    'name': '라티놀 ',
#    'new': False,
#    'new_rating': 1.4032189430079418,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 20:50',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352565867',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200045.413358418,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.11624649859944,
#    'review_count': 714,
#    'review_image_count': 60,
#    'section': 'contract',
#    'section_pos': 1,
#    'slug': '라티놀',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['CESCO', 'excellent'],
#    'takeout': False,
#    'threshold': 7500,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 동작구 상도동 504번지 102호 빙수빙수악마떡볶이',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 14000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 3.0041753328491785,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 233631,
#    'is_hotdeal': False,
#    'keywords': '아부지밥 주류 소주（참이슬） 사이드메뉴 치킨텐더（10조각） 주류 소주（처음처럼） 주류 병맥주（카스） 사이드메뉴 오뎅탕大 사이드메뉴 치즈스틱（8조각） 사이드메뉴 버팔로윙（10조각） 사이드메뉴 치킨텐더（5조각） 파스타메뉴 매운토마토스파게티 파스타메뉴 치즈오븐매운토마토스파게티',
#    'lat': 37.4946422,
#    'list_pos': 3,
#    'lng': 126.9575429,
#    'logo_url': '/media/restaurant_logos/아부지밥_20160311_가맹로고이미지약정서_crop_200x200.jpg',
#    'loyal_score': 30.485445356496,
#    'min_order_amount': 14000,
#    'name': '아부지밥',
#    'new': False,
#    'new_rating': 1.2194178142598402,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 22:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352592891',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200048.685445357,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.00735294117647,
#    'review_count': 136,
#    'review_image_count': 28,
#    'section': 'contract',
#    'section_pos': 2,
#    'slug': '아부지밥',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 2000,
#    'additional_discount_currently_active': True,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1643-5 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.0167376472982876,
#    'except_cash': False,
#    'franchise_id': 37,
#    'franchise_name': '(유)비에이치씨 / BHC치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 218087,
#    'is_hotdeal': True,
#    'keywords': 'BHC-낙성대점 <후라이드> 쏘스에무쵸 <후라이드> 쏘스에무쵸HOT <양념／순살> 치킨강정 <후라이드> 별코치（별에서온코스치킨） <콜라／무／소스> 커리딥소스 <콜팝> 콜팝치킨 <양념／순살> 순살치킨강정 <콜라／무／소스> 뿌링뿌링소스 <콜팝> 미니콜팝 <뿌링클> 바삭클',
#    'lat': 37.4740522999295,
#    'list_pos': 4,
#    'lng': 126.9680474,
#    'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_uetXCQA.JPG',
#    'loyal_score': 15.9383967252744,
#    'min_order_amount': 15000,
#    'name': 'BHC-낙성대점',
#    'new': False,
#    'new_rating': 1.0341883395513185,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 23:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352576215',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200035.341442411,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 4.575,
#    'review_count': 200,
#    'review_image_count': 46,
#    'section': 'contract',
#    'section_pos': 3,
#    'slug': 'bhc치킨-낙성대점',
#    'sms_bonus': True,
#    'subtitle': '',
#    'tags': ['CESCO'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1521-35 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식', '일식돈까스', '분식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 13000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.3750803790507447,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 242628,
#    'is_hotdeal': False,
#    'keywords': '돈스앤김밥-봉천점 면류 떡만두국 면류 물냉면 사이드메뉴 콜라1.25L 면류 우동 밥류&찌개류 김치찌개 면류 떡국 면류 냉모밀 밥류&찌개류 김치볶음밥 밥류&찌개류 새우볶음밥 사이드메뉴 사이다1.25L',
#    'lat': 37.4821374,
#    'list_pos': 5,
#    'lng': 126.9399649,
#    'logo_url': '/media/restaurant_logos/김밥세트03_20131128_FoodAD_crop_200x200_ufekvMY.jpg',
#    'loyal_score': 0.0,
#    'min_order_amount': 13000,
#    'name': '돈스앤김밥-봉천점',
#    'new': True,
#    'new_rating': 0.12498392418985109,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 22:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050712902838',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200002.0,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 0.0,
#    'review_count': 0,
#    'review_image_count': 0,
#    'section': 'contract',
#    'section_pos': 4,
#    'slug': '돈스앤김밥-봉천점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 7500,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 40-39 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '피자양식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 12900원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': '2016-11-13T12:00:00',
#    'discount_percent': 10,
#    'discount_until': '2016-11-13T20:59:59.999999',
#    'distance': 2.1247833735392,
#    'except_cash': False,
#    'franchise_id': 3,
#    'franchise_name': '(주)반올림피자샵 / 피자샵',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 241478,
#    'is_hotdeal': False,
#    'keywords': '피자샵-봉천점 피자L메뉴 크림치즈피자L 하프앤하프XXXL메뉴 하프앤하프크림치즈피자몬스터 하프앤하프XXXL메뉴 하프앤하프바이트피자몬스터 세트메뉴 세트8（오리지널피자R＋오븐스파게티＋버팔로윙＋훈제치킨＋콜라1.25L） 사이드메뉴 핫칠리스파게티 하프앤하프L메뉴 하프앤하프크림치즈피자L 피자XXXL메뉴 골드피자몬스터 하프앤하프XXXL메뉴 하프앤하프리치골드피자몬스터 피자XXXL메뉴 크림치즈피자몬스터 피자R메뉴 크림치즈피자R',
#    'lat': 37.4866166,
#    'list_pos': 6,
#    'lng': 126.9565252,
#    'logo_url': '/media/restaurant_logos/피자샵_20160325_Franchise이미지약정서_crop_200x200_j0clHag.jpg',
#    'loyal_score': 0.596990801066598,
#    'min_order_amount': 12900,
#    'name': '피자샵-봉천점',
#    'new': False,
#    'new_rating': 0.1989229573348239,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 23:40',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050712901732',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200020.176990801,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 4.7,
#    'review_count': 10,
#    'review_image_count': 8,
#    'section': 'contract',
#    'section_pos': 5,
#    'slug': '피자샵-봉천점',
#    'sms_bonus': True,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 금천구 독산동 958-63 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['분식', '한식', '일식돈까스', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 14000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 5.1545276441588115,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 67988,
#    'is_hotdeal': False,
#    'keywords': '식객도시락 한식류 순살윙도시락 한식류 윙봉도시락 스페셜돈까스 스페셜돈까스（생선） 스페셜돈까스 스페셜돈까스（치즈치킨） 스페셜돈까스 스페셜돈까스（등심） 분식류 떡볶이 스페셜메뉴 스페셜메뉴（돈까스＋새우튀김） 돈까스류 미트볼 스페셜메뉴 스페셜메뉴（제육볶음＋새우튀김） 한식류 소갈비정식',
#    'lat': 37.4782197,
#    'list_pos': 7,
#    'lng': 126.9029005,
#    'logo_url': '/media/restaurant_logos/제육정식01_20131128_FoodAD_crop_200x200_raIkK1T.jpg',
#    'loyal_score': 25.1362981076481,
#    'min_order_amount': 14000,
#    'name': '식객도시락',
#    'new': False,
#    'new_rating': 1.005451924305924,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 09:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352564394',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200042.057204031,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.56410256410256,
#    'review_count': 585,
#    'review_image_count': 77,
#    'section': 'contract',
#    'section_pos': 6,
#    'slug': '식객도시락',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 7500,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1642-2',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 0.9674682114846802,
#    'except_cash': False,
#    'franchise_id': 18,
#    'franchise_name': '(주)GNFOOD(지엔푸드) / 굽네치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 2888,
#    'is_hotdeal': True,
#    'keywords': '굽네치킨-인헌점 <굽네딥치즈시리즈> 굽네딥치즈윙 <굽네볼케이노쌀떡볶이시리즈> 굽네볼케이노윙＋쌀떡볶이 <굽네볼케이노쌀떡볶이시리즈> 굽네볼케이노통다리＋쌀떡볶이 <굽네양념시리즈> 굽네양념치킨윙 <색다른메뉴> 굽네폭립 <굽네반반시리즈> 굽네반반윙（굽네오리지널윙반＋볼케이노윙반） <굽네반반시리즈> 굽네반반통다리（오리지널통다리반＋볼케이노통다리반） <굽네양념시리즈> 굽네양념치킨 <굽네후르츄소이갈릭시리즈> 굽네후르츄소이갈릭윙 <굽네오리지널콤보세트> 오리지널윙（반）＋오리지널순살（반）',
#    'lat': 37.474278,
#    'list_pos': 8,
#    'lng': 126.966932,
#    'logo_url': '/media/restaurant_logos/굽네치킨_20151119_Franchise이미지약정서_crop_200x200_9t2hNN1.JPG',
#    'loyal_score': 13.5724771127238,
#    'min_order_amount': 15000,
#    'name': '굽네치킨-인헌점',
#    'new': False,
#    'new_rating': 0.949405442212016,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 23:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352584196',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200020.989143779,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#    'review_avg': 4.16417910447761,
#    'review_count': 67,
#    'review_image_count': 7,
#    'section': 'contract',
#    'section_pos': 7,
#    'slug': '굽네치킨-인헌점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['relayo'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': 'http://www.goobne.co.kr/'},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 인헌동 1636-17',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['일식돈까스'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 20000원 이상',
#    'description': '대표메뉴는 활어회,활어초밥,싱싱해물 입니다.',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 0.9107506526872203,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 42460,
#    'is_hotdeal': False,
#    'keywords': '인헌수산활어회활어초밥전문점 안주류 멍게 안주류 해삼 회메뉴 참돔 안주류 개불 추가 콜라（500ml） 회메뉴 도다리（회） 회메뉴 농어 회메뉴 참숭어 안주류 전복 가을메뉴 가을전어',
#    'lat': 37.4744752,
#    'list_pos': 9,
#    'lng': 126.9655489,
#    'logo_url': '/media/restaurant_logos/회07_20131205_foodon_crop_200x200_10.jpg',
#    'loyal_score': 12.5018080517457,
#    'min_order_amount': 20000,
#    'name': '인헌수산활어회활어초밥전문점',
#    'new': False,
#    'new_rating': 0.9179221915323839,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 23:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352561599',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200030.711228342,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.01433691756272,
#    'review_count': 279,
#    'review_image_count': 26,
#    'section': 'contract',
#    'section_pos': 8,
#    'slug': '인헌회초밥전문점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 금천구 독산동 958-63 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 14000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 5.1545276441588115,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 242762,
#    'is_hotdeal': False,
#    'keywords': '달빛포차 볶음류 오징어볶음 찜·탕류 해물찜 볶음류 고추장삼겹볶음 볶음류 낙지볶음 볶음류 소불고기볶음 볶음류 돼지불고기볶음 안주거리 김치두루치기 볶음류 곱창볶음 안주거리 두부김치 안주거리 한방삼계탕',
#    'lat': 37.4782197,
#    'list_pos': 10,
#    'lng': 126.9029005,
#    'logo_url': '/media/restaurant_logos/닭볶음탕02_20131128_FoodAD_crop_200x200_aMq8unE.jpg',
#    'loyal_score': -0.251644495611922,
#    'min_order_amount': 14000,
#    'name': '달빛포차',
#    'new': True,
#    'new_rating': -0.01006577982447688,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 09:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050712902858',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200013.748355504,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 1.0,
#    'review_count': 1,
#    'review_image_count': 0,
#    'section': 'contract',
#    'section_pos': 9,
#    'slug': '달빛포차',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 886-17',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['피자양식', '야식', '치킨', '프랜차이즈'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 13900원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.0122296940956765,
#    'except_cash': False,
#    'franchise_id': 39,
#    'franchise_name': '(주)디에스푸드 / 피자와치킨의러브레터',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 7777,
#    'is_hotdeal': False,
#    'keywords': '피자와치킨의러브레터-봉천점 CHICKENMENU 양파치킨 CHICKENMENU 양파순살치킨 PIZZA（L）&CHICKENMENU-치킨반마리 스위트더블치킨피자L＋케이준치킨반마리＋콜라1.25L CHICKENMENU 양념치킨 PIZZA（L）&CHICKENMENU-치킨반마리 로얄포테이토피자L＋케이준치킨반마리＋콜라1.25L CHICKENMENU 쏘이치킨（간장맛） PIZZA（M）&CHICKENMENU-치킨한마리 로얄포테이토피자M＋케이준치킨한마리＋콜라500mL PIZZA（L）&CHICKENMENU-치킨반마리 퐁듀피자L＋케이준치킨반마리＋콜라1.25L 추가&음료메뉴 콜라500mL PIZZA（L）&CHICKENMENU-치킨반마리 치즈피자L＋케이준치킨반마리＋콜라1.25L',
#    'lat': 37.4833713,
#    'list_pos': 11,
#    'lng': 126.9484143,
#    'logo_url': '/media/restaurant_logos/피자와치킨의러브레터_20160714_Franchise이미지약정서_crop_200x200_pYag89O.jpg',
#    'loyal_score': 17.3797863444295,
#    'min_order_amount': 13900,
#    'name': '피자와치킨의러브레터-봉천점',
#    'new': False,
#    'new_rating': 0.8927455149580449,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 00:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352570170',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200034.049931975,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.36602870813397,
#    'review_count': 418,
#    'review_image_count': 31,
#    'section': 'contract',
#    'section_pos': 10,
#    'slug': '피자와치킨의러브레터(봉천점)',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 금천구 독산동 958-63 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 19000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 5.1545276441588115,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 38351,
#    'is_hotdeal': False,
#    'keywords': '야간매점 쌈밥류 족발쌈밥 탕류／기타 매운떡볶이 쌈밥류 쭈꾸미쌈밥 찜류 묵은지수육찜 쌈밥류 고추장쌈밥 쌈밥류 오징어쌈밥 스페셜메뉴 떡볶이세트（매운세트） 쌈밥류 오삼쌈밥 쌈밥류 낙지쌈밥 쌈밥류 쭈삼쌈밥',
#    'lat': 37.4782197,
#    'list_pos': 12,
#    'lng': 126.9029005,
#    'logo_url': '/media/restaurant_logos/닭볶음탕03_20131128_FoodAD_crop_200x200_10.jpg',
#    'loyal_score': 22.0443528601241,
#    'min_order_amount': 19000,
#    'name': '야간매점',
#    'new': False,
#    'new_rating': 0.881774114404964,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 09:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352558298',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200039.229695445,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.79727427597956,
#    'review_count': 1174,
#    'review_image_count': 74,
#    'section': 'contract',
#    'section_pos': 11,
#    'slug': '이모네TB276Q',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 466-76 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '야식', '치킨'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.355246313525189,
#    'except_cash': False,
#    'franchise_id': 18,
#    'franchise_name': '(주)GNFOOD(지엔푸드) / 굽네치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 2884,
#    'is_hotdeal': True,
#    'keywords': '굽네치킨-성현점 <굽네양념시리즈> 굽네양념치킨순살 <굽네후르츄소이갈릭시리즈> 굽네후르츄소이갈릭윙 <굽네딥치즈시리즈> 굽네딥치즈윙 <굽네오리지널콤보세트> 오리지널윙（반）＋오리지널순살（반） <굽네볼케이노쌀떡볶이시리즈> 굽네볼케이노윙＋쌀떡볶이 <굽네볼케이노모짜렐라시리즈> 굽네볼케이노윙＋모짜렐라치즈 <굽네양념시리즈> 굽네양념치킨윙 <음료메뉴> 보헤미안스파클링（탄산수）-플레인350ml <굽네볼케이노시리즈> 굽네볼케이노통다리 <색다른메뉴> 굽네불닭발',
#    'lat': 37.4870237,
#    'list_pos': 13,
#    'lng': 126.9488973,
#    'logo_url': '/media/restaurant_logos/굽네치킨_20151119_Franchise이미지약정서_crop_200x200_cm2zsBu.JPG',
#    'loyal_score': 18.2817481876593,
#    'min_order_amount': 15000,
#    'name': '굽네치킨-성현점',
#    'new': False,
#    'new_rating': 0.8602206648013343,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 00:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352564462',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200025.778487318,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#    'review_avg': 4.22826086956522,
#    'review_count': 92,
#    'review_image_count': 18,
#    'section': 'contract',
#    'section_pos': 12,
#    'slug': '굽네치킨-성현점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['relayo'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': 'http://www.goobne.co.kr/'},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1589-9번지',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.3450985835917362,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 217006,
#    'is_hotdeal': False,
#    'keywords': '마초불닭-서울대점 사이드메뉴 오뎅탕 사이드메뉴 누룽지탕 사이드메뉴 쿨피스930mL 기본메뉴 닭볶음탕 사이드메뉴 계란찜 기본메뉴 국물닭발 사이드메뉴 공기밥 세트메뉴 세트2（닭볶음탕＋계란찜＋주먹밥＋쿨피스930mL） 기본메뉴 통뼈닭발 사이드메뉴 주먹밥',
#    'lat': 37.4777041,
#    'list_pos': 14,
#    'lng': 126.9512426,
#    'logo_url': '/media/restaurant_logos/양념닭발01_20131128_FoodAD_crop_200x200_NSx24bR.jpg',
#    'loyal_score': 12.2085978747378,
#    'min_order_amount': 15000,
#    'name': '마초불닭-서울대점',
#    'new': False,
#    'new_rating': 0.8193241982711648,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:30 - 00:50',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352575016',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200030.740820097,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 4.23913043478261,
#    'review_count': 92,
#    'review_image_count': 19,
#    'section': 'contract',
#    'section_pos': 13,
#    'slug': '마초불닭-서울대점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1584-2',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨', '테이크아웃', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.6177233992610986,
#    'except_cash': False,
#    'franchise_id': 9,
#    'franchise_name': '(주)농협목우촌 / 또래오래',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 26299,
#    'is_hotdeal': True,
#    'keywords': '또래오래-관악봉천1호점 치킨메뉴 치킨애밥 사이드메뉴 김말이2개 신메뉴 리얼핫양념치킨 치킨메뉴 목우촌통날개 행복한두마리치킨 행복세트1（오곡후라이드＋오곡후라이드） 치킨메뉴 찹쌀양념치킨 치킨메뉴 스낵후라이드 사이드메뉴 사이다1.25L 추천메뉴 순살핫양념 반반메뉴 양념반＋핫양념반',
#    'lat': 37.4786613,
#    'list_pos': 15,
#    'lng': 126.9477513,
#    'logo_url': '/media/restaurant_logos/또래오래_20151126_Franchise이미지약정서_crop_200x200_obCG4kg.jpg',
#    'loyal_score': 12.1976434836714,
#    'min_order_amount': 15000,
#    'name': '또래오래-관악봉천1호점',
#    'new': False,
#    'new_rating': 0.7643610594946363,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 02:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352564364',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200030.599620885,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 4.16201117318436,
#    'review_count': 358,
#    'review_image_count': 54,
#    'section': 'contract',
#    'section_pos': 14,
#    'slug': '또래오래-관악봉천1호점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': True,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 945-1',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '피자양식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.5049006078594527,
#    'except_cash': False,
#    'franchise_id': 44,
#    'franchise_name': '(주)피자헤븐 / 피자헤븐',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 28417,
#    'is_hotdeal': True,
#    'keywords': '김준현의피자헤븐-신림봉천점 사이드메뉴 씨푸드포모도로 피자Large메뉴 통가슴살치킨L 피자Large메뉴 치킨바베큐피자L 피자Medium메뉴 크랜베리고르곤졸라M 피자Medium메뉴 더블포테이토M 피자Medium메뉴 통가슴살치킨M 피자Medium메뉴 치킨바베큐피자M 피자Large메뉴 쿼터드레싱포테이토L 피자BigLarge메뉴 로얄쿼터블피자BIGL 피자BigLarge메뉴 크랜베리고르곤졸라BIGL',
#    'lat': 37.4831579,
#    'list_pos': 16,
#    'lng': 126.9391523,
#    'logo_url': '/media/restaurant_logos/피자헤븐_20161011_Franchise이미지약정서_crop_200x200.jpg',
#    'loyal_score': 16.0735664565831,
#    'min_order_amount': 12000,
#    'name': '김준현의 피자헤븐-신림봉천점',
#    'new': False,
#    'new_rating': 0.7419625366914335,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 23:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352559323',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200034.587875667,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.23770491803279,
#    'review_count': 610,
#    'review_image_count': 43,
#    'section': 'contract',
#    'section_pos': 15,
#    'slug': '피자헤븐테이스트-신림봉천점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent', 'CESCO'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 행운동 1674-26 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '중식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.3590572417381042,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 137,
#    'is_hotdeal': False,
#    'keywords': '다빈(행운동) 요리부 잡탕 요리부 해삼탕 요리부 전가복 요리부 유린기 요리코스 C코스 요리부 부추잡채 요리부 누룽지탕 요리코스 B코스 알뜰세트메뉴 9번세트 요리부 라조기',
#    'lat': 37.4798331,
#    'list_pos': 17,
#    'lng': 126.9581044,
#    'logo_url': '/media/restaurant_logos/탕수육01_20120524_FoodAD_crop_6.jpg',
#    'loyal_score': 9.92069739435604,
#    'min_order_amount': 10000,
#    'name': '다빈(행운동)',
#    'new': False,
#    'new_rating': 0.7250164474266207,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 23:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352561514',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200026.897874572,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.61102831594635,
#    'review_count': 671,
#    'review_image_count': 10,
#    'section': 'contract',
#    'section_pos': 16,
#    'slug': '다빈',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 5000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1644-5',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['중식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 0.9926473716363329,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 25925,
#    'is_hotdeal': False,
#    'keywords': '향도장-봉천동 요리부 라조육 요리부 계란탕 요리부 깐풍새우 요리부 잡탕 셋트메뉴 세트8（유산슬＋짜장1＋짬뽕1） 셋트메뉴 세트8（유산슬＋짜장or짬뽕2） 요리부 잡채 요리부 고기튀김 요리부 유산슬 셋트메뉴 세트6（팔보채＋짜장1＋짬뽕1）',
#    'lat': 37.4745017,
#    'list_pos': 18,
#    'lng': 126.9670412,
#    'logo_url': '/media/restaurant_logos/짜장면01_20120524_FoodAD_crop_200x200_414.jpg',
#    'loyal_score': 7.72099339472676,
#    'min_order_amount': 12000,
#    'name': '향도장-봉천동',
#    'new': False,
#    'new_rating': 0.7103102614618038,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 21:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352566943',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200023.073850538,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.95714285714286,
#    'review_count': 70,
#    'review_image_count': 1,
#    'section': 'contract',
#    'section_pos': 17,
#    'slug': '향도장(인헌동)',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 5000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 2000,
#    'additional_discount_currently_active': True,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1540-1 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.0099754369557976,
#    'except_cash': False,
#    'franchise_id': 37,
#    'franchise_name': '(유)비에이치씨 / BHC치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 229517,
#    'is_hotdeal': True,
#    'keywords': 'BHC-봉천청룡점 <콜팝> 후렌치콜팝 <콜팝> 왕콜팝 <양념／순살> 매운맛양념치킨 <콜라／무／소스> 커리딥소스 <양념／순살> 치킨강정 <콜팝> 떡강정콜팝 <간장／구이> 간장골드닭다리 <콜라／무／소스> 뿌링뿌링소스 <콜팝> 빅콜팝 <콜팝> 미니콜팝',
#    'lat': 37.4795096,
#    'list_pos': 19,
#    'lng': 126.9425553,
#    'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_oJ00D1r.JPG',
#    'loyal_score': 12.5887745892861,
#    'min_order_amount': 15000,
#    'name': 'BHC-봉천청룡점',
#    'new': False,
#    'new_rating': 0.7015558961802845,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 01:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352588087',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200028.152009883,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#    'review_avg': 4.27142857142857,
#    'review_count': 140,
#    'review_image_count': 28,
#    'section': 'contract',
#    'section_pos': 18,
#    'slug': 'bhc-봉천청룡점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['CESCO', 'relayo'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 916-16 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['중식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.8385443676194893,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 120689,
#    'is_hotdeal': False,
#    'keywords': '동원각-봉천점 요리세트 요리세트4（양장피＋등심탕수육＋고추잡채＋군만두） 면류 삼선우동 요리메뉴 깐풍새우 요리메뉴 잡탕 요리메뉴 라조기 요리메뉴 마파두부 면류 기스면 밥류 오징어덮밥 요리메뉴 해삼쥬스 세트메뉴 세트메뉴7（유산슬＋짜장2）',
#    'lat': 37.480028,
#    'list_pos': 20,
#    'lng': 126.9459205,
#    'logo_url': '/media/restaurant_logos/코스요리세트03_20131213_foodon_crop_200x200_55GEKQu.jpg',
#    'loyal_score': 10.9398752567642,
#    'min_order_amount': 10000,
#    'name': '동원각-봉천점',
#    'new': False,
#    'new_rating': 0.6698861367466702,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:30 - 21:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352445009',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200026.302587121,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 3.98412698412698,
#    'review_count': 63,
#    'review_image_count': 14,
#    'section': 'contract',
#    'section_pos': 19,
#    'slug': '동원각-봉천점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 5000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''}]}

# %%
# 1. 정적인 사이트
# 2. 동적인 사이트 
# 3, 4. selenium - integration test ( 브라우저에서 테스트 )

# -----
# numpy.ndarray,
# pandas.Series, pandas.DataFrame
#

# 1. Data Types, 조건문, 반복문, 함수, + Lambda Operator, List Comprehension
# 2. Data 수집하기 => 1. 정적인 사이트, 2. 동적인 사이트 

# 3. Numpy ( 다차원 벡터; 행렬 ) - 이미지 , 영상 
# 4. Pandas ( 엑셀, 시계열 데이터 ) - 주가. 엑셀++

# 5. Matplotlib
# 데이터 분석 프로세스

# %%
from selenium import webdriver

# %%
driver = webdriver.PhantomJS()

# %%
driver.get("http://naver.com")

# %%
from IPython.display import Image

# %%
driver.get("https://nid.naver.com/nidlogin.login")

# %%
driver.find_element_by_css_selector("#id").send_keys("saltman21")

# %%
Image(driver.get_screenshot_as_png())

# %%
data = data[:5]

# %%
data
# Out:
# [{'deposit': 2000, 'rent': 60},
#  {'deposit': 300, 'rent': 29},
#  {'deposit': 23000, 'rent': 0},
#  {'deposit': 500, 'rent': 55},
#  {'deposit': 1000, 'rent': 44}]

# %%
# 2000 300 23000 500 1000
#     2300 25300 500 1000

# $ requests, beautifulsoup4
# $ numpy, pandas

# %%
def temp_func(x, y):
    sum_deposit = x["deposit"] + y["deposit"]
    sum_rent = x["rent"] + y["rent"]
    return {
        "deposit": sum_deposit,
        "rent": sum_rent,
    }

# map, filter, ... , reduce(o o => x)
reduce(
    temp_func,
    data,
)                 # 히스토그램 => {...}
# Out:
# {'deposit': 26800, 'rent': 188}

# %%
deposit_rent_sum = reduce(
    lambda a, b: {
        "deposit": a["deposit"] + b["deposit"],
        "rent": a["rent"] + b["rent"],
    },
    data,
)
